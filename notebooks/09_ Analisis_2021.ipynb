# %%
# Tratamiento de datos
import pandas as pd
# Ignorar warnings
import warnings
warnings.filterwarnings("ignore")
# Configuración
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames
#importar la biblioteca de numpy:
import numpy as np
import os
import sys #permite navegar por el sistema
sys.path.append("../") #solo aplica al soporte
import src.soporte_EDA as se


pd.options.display.float_format = '{:.2f}'.format # para redondearlo todo a 2 decimales

# %%
os.listdir('../datos/raw/')
# Out:
# ['datos-2013.csv',
#  'datos-2014.csv',
#  'datos-2015.csv',
#  'datos-2016.csv',
#  'datos-2017.csv',
#  'datos-2018.csv',
#  'datos-2019.csv',
#  'datos-2020.csv',
#  'datos-2021.csv',
#  'diccionario_datos.csv']

# %%
lista_archivos = os.listdir('../datos/raw/')[:-1]
lista_archivos
# Out:
# ['datos-2013.csv',
#  'datos-2014.csv',
#  'datos-2015.csv',
#  'datos-2016.csv',
#  'datos-2017.csv',
#  'datos-2018.csv',
#  'datos-2019.csv',
#  'datos-2020.csv',
#  'datos-2021.csv']

# %%
diccionario = se.carga_ficheros_csv('raw',lista_archivos)

# %%
df_datos_2013 = diccionario['df_2013']
df_datos_2014 = diccionario['df_2014']
df_datos_2015 = diccionario['df_2015']
df_datos_2016 = diccionario['df_2016']
df_datos_2017 = diccionario['df_2017']
df_datos_2018 = diccionario['df_2018']
df_datos_2019 = diccionario['df_2019']
df_datos_2020 = diccionario['df_2020']
df_datos_2021 = diccionario['df_2021']

# %% [markdown]
# # Anális datos año 2021

# %%
se.traducción_columnas(df_datos_2021)

# %%
df_datos_2021
# Out:
#         CÓDIGO_ÓRGANO_SUPERIOR                         NOMBRE_ÓRGANO_SUPERIOR  \
# 0                        63000                       Advocacia-Geral da União
# 1                        63000                       Advocacia-Geral da União
# 2                        37000                   Controladoria-Geral da União
# 3                        22000  Ministério da Agricultura, Pecuária e Abastec
# 4                        22000  Ministério da Agricultura, Pecuária e Abastec
# ...                        ...                                            ...
# 134588                   20000                       Presidência da República
# 134589                   20000                       Presidência da República
# 134590                   20000                       Presidência da República
# 134591                   20000                       Presidência da República
# 134592                   20000                       Presidência da República
#
# ...

# %%
se.reporte(df_datos_2021)
# Out:
# La tabla tiene 134593 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                            tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              int64          134593             0
# NOMBRE_ÓRGANO_SUPERIOR             object          134593             0
# CÓDIGO_ÓRGANO                       int64          134593             0
# NOMBRE_ÓRGANO                      object          134593             0
# CÓDIGO_UNIDAD_GESTORA               int64          134593             0
# NOMBRE_UNIDAD_GESTORA              object          134593             0
# CATEGORÍA_ECONÓMICA                object          134593             0
# ORIGEN_INGRESO                     object          134593             0
# TIPO_INGRESO                       object          134593             0
# DETALLE                            object          134593             0
# VALOR_PREVISTO_ACTUALIZADO         object          134593             0
# ...

# %%
se.conversion_columnas(df_datos_2021)
# Out:
# La tabla tiene 134593 filas y 16 columnas
# La tabla tiene 0 filas duplicadas
#                             tipo_variables  contador_total  numero_nulos  \
# CÓDIGO_ÓRGANO_SUPERIOR              object          134593             0
# NOMBRE_ÓRGANO_SUPERIOR              object          134593             0
# CÓDIGO_ÓRGANO                       object          134593             0
# NOMBRE_ÓRGANO                       object          134593             0
# CÓDIGO_UNIDAD_GESTORA               object          134593             0
# NOMBRE_UNIDAD_GESTORA               object          134593             0
# CATEGORÍA_ECONÓMICA                 object          134593             0
# ORIGEN_INGRESO                      object          134593             0
# TIPO_INGRESO                        object          134593             0
# DETALLE                             object          134593             0
# VALOR_PREVISTO_ACTUALIZADO         float64          134593             0
# ...

# %%
se.analisis_descriptivos_categóricas(df_datos_2021)
# Out:
# Las columnas categóricas son Index(['CÓDIGO_ÓRGANO_SUPERIOR', 'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO',
#        'NOMBRE_ÓRGANO', 'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA',
#        'CATEGORÍA_ECONÓMICA', 'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE'],
#       dtype='object')
# Algunos ejemplos de filas son:
#        CÓDIGO_ÓRGANO_SUPERIOR  NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 112742                  36000     Ministério da Saúde         36213
# 49778                   25000  Ministério da Economia         25000
# 16750                   52000    Ministério da Defesa         52221
# 84941                   26000  Ministério da Educação         26285
# 62154                   26000  Ministério da Educação         26406
#
#                                             NOMBRE_ÓRGANO  \
# 112742              Agência Nacional de Saúde Suplementar
# 49778   Ministério da Economia - Unidades com vínculo ...
# 16750              Indústria de Material Bélico do Brasil
# ...

# %%
se.analisis_descriptivos_numéricas(df_datos_2021)
# Out:
# Las columnas no categóricas son Index(['VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO', 'VALOR_REALIZADO',
#        'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')
# Algunos ejemplos de filas son:
#         VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  VALOR_REALIZADO  \
# 64484                         0.00              0.00          1629.00
# 37399                         0.00              0.00          2340.62
# 10340                         0.00              0.00           443.94
# 121291                        0.00              0.00      33749135.02
# 28424                         0.00              0.00       1429381.48
#
#         PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO
# 64484                   0.00     2021-11-09           2021
# 37399                   0.00     2021-09-17           2021
# 10340                   0.00     2021-06-02           2021
# 121291                  0.00     2021-08-13           2021
# ...

# %% [markdown]
# # Análisis columnas de forma individual
# ## Año 2021

# %%
for columna in df_datos_2021.columns:
    print(se.analisis_individual_columnas(df_datos_2021, columna))
# Out:
# La categoría CÓDIGO_ÓRGANO_SUPERIOR tiene 20 elementos diferentes:
#
# Los elementos de la categoría son:
# array(['63000', '37000', '22000', '55000', '24000', '52000', '25000',
#        '26000', '39000', '30000', '81000', '36000', '41000', '57000',
#        '35000', '32000', '53000', '44000', '54000', '20000'], dtype=object)
# Los 10 CÓDIGO_ÓRGANO_SUPERIOR que MAS aparecen son:
#                         count  Porcentaje_recuento
# CÓDIGO_ÓRGANO_SUPERIOR
# 26000                   39869                29.62
# 25000                   33787                25.10
# 52000                   13513                10.04
# 30000                    5947                 4.42
# 22000                    5819                 4.32
# 39000                    5298                 3.94
# 24000                    4766                 3.54
# 32000                    4557                 3.39
# 41000                    4127                 3.07
# 36000                    4110                 3.05
# ...

# %%
df_datos_2021.to_pickle("../datos/output/datos_2021_convertido.pkl")
