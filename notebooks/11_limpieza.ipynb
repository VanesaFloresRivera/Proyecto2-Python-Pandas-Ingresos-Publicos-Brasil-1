# %%
# Tratamiento de datos
import pandas as pd
# Ignorar warnings
import warnings
warnings.filterwarnings("ignore")
# Configuración
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames
#importar la biblioteca de numpy:
import numpy as np
import os
import sys #permite navegar por el sistema
sys.path.append("../") #solo aplica al soporte
import src.soporte_EDA as se


pd.options.display.float_format = '{:.2f}'.format # para redondearlo todo a 2 decimales

# %%
os.listdir('../datos/output/')
# Out:
# ['datos_2013_convertido.pkl',
#  'datos_2014_convertido.pkl',
#  'datos_2015_convertido.pkl',
#  'datos_2016_convertido.pkl',
#  'datos_2017_convertido.pkl',
#  'datos_2018_convertido.pkl',
#  'datos_2019_convertido.pkl',
#  'datos_2020_convertido.pkl',
#  'datos_2021_convertido.pkl',
#  'datos_all_v0.pkl',
#  'datos_all_v1.pkl',
#  'datos_convertido.pkl']

# %%
lista_archivos = os.listdir('../datos/output/')[:-1]
lista_archivos
# Out:
# ['datos_2013_convertido.pkl',
#  'datos_2014_convertido.pkl',
#  'datos_2015_convertido.pkl',
#  'datos_2016_convertido.pkl',
#  'datos_2017_convertido.pkl',
#  'datos_2018_convertido.pkl',
#  'datos_2019_convertido.pkl',
#  'datos_2020_convertido.pkl',
#  'datos_2021_convertido.pkl',
#  'datos_all_v0.pkl',
#  'datos_all_v1.pkl']

# %%
lista_archivos = os.listdir('../datos/output/')[:-1]
lista_archivos
# Out:
# ['datos_2013_convertido.pkl',
#  'datos_2014_convertido.pkl',
#  'datos_2015_convertido.pkl',
#  'datos_2016_convertido.pkl',
#  'datos_2017_convertido.pkl',
#  'datos_2018_convertido.pkl',
#  'datos_2019_convertido.pkl',
#  'datos_2020_convertido.pkl',
#  'datos_2021_convertido.pkl',
#  'datos_all_v0.pkl',
#  'datos_all_v1.pkl']

# %%
diccionario = se.carga_ficheros_pkl('output',lista_archivos)

# %%
df_datos_2013 = diccionario['df_2013']
df_datos_2014 = diccionario['df_2014']
df_datos_2015 = diccionario['df_2015']
df_datos_2016 = diccionario['df_2016']
df_datos_2017 = diccionario['df_2017']
df_datos_2018 = diccionario['df_2018']
df_datos_2019 = diccionario['df_2019']
df_datos_2020 = diccionario['df_2020']
df_datos_2021 = diccionario['df_2021']

# %%
df_total_anos = pd.read_pickle(f"../datos/output/datos_all_v0.pkl")

# %%
df_diccionario_datos = pd.read_pickle(f"../datos/output/datos_convertido.pkl")

# %%
df_total_anos.columns
# Out:
# Index(['INDICE_DF_AÑO_ORIGINAL', 'CÓDIGO_ÓRGANO_SUPERIOR',
#        'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO', 'NOMBRE_ÓRGANO',
#        'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA', 'CATEGORÍA_ECONÓMICA',
#        'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE',
#        'VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO', 'VALOR_REALIZADO',
#        'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')

# %% [markdown]
# ## Análisis variables numéricas

# %%
se.analisis_descriptivos_numéricas(df_total_anos)
# Out:
# Las columnas no categóricas son Index(['INDICE_DF_AÑO_ORIGINAL', 'VALOR_PREVISTO_ACTUALIZADO',
#        'VALOR_REGISTRADO', 'VALOR_REALIZADO', 'PORCENTAJE_REALIZADO',
#        'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')
# Algunos ejemplos de filas son:
#         INDICE_DF_AÑO_ORIGINAL  VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  \
# 927006                   35300                        0.00              0.00
# 976158                   84452                        0.00              0.00
# 322203                  114096                        0.00              0.00
# 933124                   41418                        0.00              0.00
# 205898                  192324                        0.00              0.00
#
#         VALOR_REALIZADO  PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO
# 927006           833.40                  0.00     2021-11-24           2021
# 976158          2050.00                  0.00     2021-09-22           2021
# ...

# %%
df_importes_agrupación_organo_superior = df_total_anos.groupby('NOMBRE_ÓRGANO_SUPERIOR')[['VALOR_PREVISTO_ACTUALIZADO',
       'VALOR_REGISTRADO', 'VALOR_REALIZADO', 'PORCENTAJE_REALIZADO']].sum()

df_importes_agrupación_organo_superior
# Out:
#                                                VALOR_PREVISTO_ACTUALIZADO  \
# NOMBRE_ÓRGANO_SUPERIOR
# Advocacia-Geral da União                                    3726053651.00
# Controladoria-Geral da União                                 740692856.00
# Ministério da Agricultura, Pecuária e Abastec              87492532893.00
# Ministério da Cidadania                                    43958882249.00
# Ministério da Ciência, Tecnologia, Inovações               62254372476.31
# Ministério da Defesa                                      198522792044.00
# Ministério da Economia                                  26486420136019.00
# Ministério da Educação                                    609585887826.00
# Ministério da Infraestrutura                              119972882836.00
# Ministério da Justiça e Segurança Pública                  36304805355.02
# Ministério da Mulher, Família e Direitos Huma                843366940.00
# ...

# %%
df_importes_agrupación_organo_superior["VALOR_REALIZADO/VALOR_PREVISTO_ACTUALIZADO"] = (df_importes_agrupación_organo_superior.VALOR_REALIZADO/df_importes_agrupación_organo_superior.VALOR_PREVISTO_ACTUALIZADO)*100

# %%
df_importes_agrupación_organo_superior["VALOR_REGISTRADO/VALOR_PREVISTO_ACTUALIZADO"] =(df_importes_agrupación_organo_superior.VALOR_REGISTRADO/df_importes_agrupación_organo_superior.VALOR_PREVISTO_ACTUALIZADO)*100

# %%
df_importes_agrupación_organo_superior
# Out:
#                                                VALOR_PREVISTO_ACTUALIZADO  \
# NOMBRE_ÓRGANO_SUPERIOR
# Advocacia-Geral da União                                    3726053651.00
# Controladoria-Geral da União                                 740692856.00
# Ministério da Agricultura, Pecuária e Abastec              87492532893.00
# Ministério da Cidadania                                    43958882249.00
# Ministério da Ciência, Tecnologia, Inovações               62254372476.31
# Ministério da Defesa                                      198522792044.00
# Ministério da Economia                                  26486420136019.00
# Ministério da Educação                                    609585887826.00
# Ministério da Infraestrutura                              119972882836.00
# Ministério da Justiça e Segurança Pública                  36304805355.02
# Ministério da Mulher, Família e Direitos Huma                843366940.00
# ...

# %%
df_total_anos.groupby('NOMBRE_ÓRGANO_SUPERIOR')[['VALOR_PREVISTO_ACTUALIZADO',
       'VALOR_REGISTRADO', 'VALOR_REALIZADO', 'PORCENTAJE_REALIZADO']].mean()
# Out:
#                                                VALOR_PREVISTO_ACTUALIZADO  \
# NOMBRE_ÓRGANO_SUPERIOR
# Advocacia-Geral da União                                        955643.41
# Controladoria-Geral da União                                   2939257.37
# Ministério da Agricultura, Pecuária e Abastec                  1894474.87
# Ministério da Cidadania                                        7453184.51
# Ministério da Ciência, Tecnologia, Inovações                   1895341.06
# Ministério da Defesa                                           2078990.39
# Ministério da Economia                                       127599892.74
# Ministério da Educação                                         1684446.11
# Ministério da Infraestrutura                                   3201325.72
# Ministério da Justiça e Segurança Pública                       908074.17
# Ministério da Mulher, Família e Direitos Huma                   728925.62
# ...

# %%
df_sin_fechas = df_total_anos[df_total_anos.FECHA_REGISTRO.isnull()]

# %%
df_sin_fechas
# Out:
#          INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 31715                     18141                  24000
# 50971                     37397                  25000
# 51032                     37458                  25000
# 51747                     38173                  25000
# 51977                     38403                  25000
# ...                         ...                    ...
# 1012711                  121005                  32000
# 1012968                  121262                  32000
# 1012994                  121288                  32000
# 1013991                  122285                  32000
# 1025473                  133767                  54000
#
#                                 NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 31715    Ministério da Ciência, Tecnologia, Inovações          20501
# 50971                           Ministério da Economia         25000
# 51032                           Ministério da Economia         25000
# ...

# %%
df_total_anos.columns
# Out:
# Index(['INDICE_DF_AÑO_ORIGINAL', 'CÓDIGO_ÓRGANO_SUPERIOR',
#        'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO', 'NOMBRE_ÓRGANO',
#        'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA', 'CATEGORÍA_ECONÓMICA',
#        'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE',
#        'VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO', 'VALOR_REALIZADO',
#        'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')

# %%
df_total_anos[df_total_anos.VALOR_PREVISTO_ACTUALIZADO!=0].FECHA_REGISTRO.value_counts()
# Out:
# FECHA_REGISTRO
# 2013-12-31    2873
# 2014-12-31    2847
# 2015-12-31    2738
# 2020-01-20    1993
# 2018-01-12    1899
# 2016-01-21    1888
# 2017-01-19    1875
# 2019-01-31    1850
# 2021-04-23    1844
# 2017-01-23       6
# 2016-06-08       3
# 2017-07-25       3
# 2017-03-31       3
# 2017-03-29       3
# 2016-01-13       3
# 2019-10-11       3
# 2018-08-28       3
# 2020-07-08       3
# 2021-04-29       3
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.VALOR_REGISTRADO!=0].FECHA_REGISTRO.value_counts()
# Out:
# FECHA_REGISTRO
# 2020-02-28    108
# 2020-08-31    106
# 2021-08-24    104
# 2021-11-26    104
# 2021-06-23    103
#              ...
# 2021-01-29      1
# 2021-10-30      1
# 2021-11-05      1
# 2021-11-04      1
# 2021-05-28      1
# Name: count, Length: 253, dtype: int64

# %%
se.reporte(df_sin_fechas)
# Out:
# La tabla tiene 578 filas y 17 columnas
# La tabla tiene 0 filas duplicadas
#                             tipo_variables  contador_total  numero_nulos  \
# INDICE_DF_AÑO_ORIGINAL               int64             578             0
# CÓDIGO_ÓRGANO_SUPERIOR              object             578             0
# NOMBRE_ÓRGANO_SUPERIOR              object             578             0
# CÓDIGO_ÓRGANO                       object             578             0
# NOMBRE_ÓRGANO                       object             578             0
# CÓDIGO_UNIDAD_GESTORA               object             578             0
# NOMBRE_UNIDAD_GESTORA               object             578             0
# CATEGORÍA_ECONÓMICA                 object             578             0
# ORIGEN_INGRESO                      object             578             0
# TIPO_INGRESO                        object             578             0
# DETALLE                             object             578             0
# ...

# %%
se.analisis_descriptivos_categóricas(df_sin_fechas)
# Out:
# Las columnas categóricas son Index(['CÓDIGO_ÓRGANO_SUPERIOR', 'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO',
#        'NOMBRE_ÓRGANO', 'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA',
#        'CATEGORÍA_ECONÓMICA', 'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE'],
#       dtype='object')
# Algunos ejemplos de filas son:
#        CÓDIGO_ÓRGANO_SUPERIOR         NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 555495                  32000  Ministério de Minas e Energia         32210
# 638547                  25000         Ministério da Economia         25000
# 167760                  36000            Ministério da Saúde         36211
# 442376                  25000         Ministério da Economia         25000
# 378129                  32000  Ministério de Minas e Energia         32210
#
#                                             NOMBRE_ÓRGANO  \
# 555495               Agência Nacional de Energia Elétrica
# 638547  Ministério da Economia - Unidades com vínculo ...
# ...

# %%
se.analisis_descriptivos_numéricas(df_sin_fechas)
# Out:
# Las columnas no categóricas son Index(['INDICE_DF_AÑO_ORIGINAL', 'VALOR_PREVISTO_ACTUALIZADO',
#        'VALOR_REGISTRADO', 'VALOR_REALIZADO', 'PORCENTAJE_REALIZADO',
#        'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')
# Algunos ejemplos de filas son:
#         INDICE_DF_AÑO_ORIGINAL  VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  \
# 622727                   50197                        0.00    26394851369.87
# 53926                    40352                        0.00      461253088.72
# 429500                   30914                        0.00        6022405.57
# 547079                  148493                        0.00           5731.56
# 79366                    65792                        0.00     3628784264.61
#
#         VALOR_REALIZADO  PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO
# 622727             0.00                  0.00            NaT           2019
# 53926              0.00                  0.00            NaT           2016
# ...

# %%
se.analisis_individual_columnas(df_sin_fechas, 'VALOR_REGISTRADO')
# Out:
# La categoría VALOR_REGISTRADO tiene 525 elementos diferentes:
#
# Los elementos de la categoría son:
# array([3.66572200e+04, 2.49022960e+05, 3.28716859e+07, 1.75318081e+09,
#        2.24278206e+08, 1.59697009e+08, 1.62505906e+09, 1.06266900e+07,
#        4.61253089e+08, 2.39351900e+04, 1.67811651e+08, 3.86123456e+08,
#        1.87585199e+07, 4.37298084e+09, 3.64583552e+08, 7.72230099e+08,
#        3.05804012e+08, 3.02090411e+07, 4.46217100e+04, 5.98823147e+09,
#        5.99946658e+08, 1.73373276e+07, 3.50698951e+09, 2.25500000e+01,
#        5.42119371e+10, 8.81751081e+07, 3.17876000e+03, 1.00427594e+09,
#        3.85561000e+03, 2.38011600e+08, 3.52474793e+10, 9.60980082e+08,
#        1.21379809e+09, 1.35932921e+07, 1.08002954e+06, 5.45549386e+09,
#        1.66191611e+08, 1.15264462e+08, 1.53619347e+10, 7.53123728e+07,
#        1.39327878e+10, 1.53391973e+10, 1.91669533e+10, 2.99515389e+10,
#        2.84995700e+08, 7.63232870e+08, 1.31112728e+09, 1.12775400e+04,
# ...

# %%
df_sin_fechas[df_sin_fechas.VALOR_REGISTRADO == 0.00]
# Out:
# Empty DataFrame
# Columns: [INDICE_DF_AÑO_ORIGINAL, CÓDIGO_ÓRGANO_SUPERIOR, NOMBRE_ÓRGANO_SUPERIOR, CÓDIGO_ÓRGANO, NOMBRE_ÓRGANO, CÓDIGO_UNIDAD_GESTORA, NOMBRE_UNIDAD_GESTORA, CATEGORÍA_ECONÓMICA, ORIGEN_INGRESO, TIPO_INGRESO, DETALLE, VALOR_PREVISTO_ACTUALIZADO, VALOR_REGISTRADO, VALOR_REALIZADO, PORCENTAJE_REALIZADO, FECHA_REGISTRO, AÑO_EJERCICIO]
# Index: []

# %%
df_total_anos[df_total_anos.VALOR_REGISTRADO != 0.00]
# Out:
#          INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 590                         590                  25000
# 616                         616                  25000
# 619                         619                  25000
# 638                         638                  25000
# 648                         648                  25000
# ...                         ...                    ...
# 1025473                  133767                  54000
# 1025474                  133768                  54000
# 1025475                  133769                  54000
# 1025476                  133770                  54000
# 1025477                  133771                  54000
#
#          NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 590      Ministério da Economia         25000
# 616      Ministério da Economia         25000
# 619      Ministério da Economia         25000
# 638      Ministério da Economia         25000
# 648      Ministério da Economia         25000
# ...

# %% [markdown]
# En esta tabla parece que los apuntes negativos son anulaciones de apuntes positivos, se observa en los últimos 4 registros

# %%
se.reporte(df_total_anos[df_total_anos.VALOR_REGISTRADO != 0.00])
# Out:
# La tabla tiene 7218 filas y 17 columnas
# La tabla tiene 0 filas duplicadas
#                             tipo_variables  contador_total  numero_nulos  \
# INDICE_DF_AÑO_ORIGINAL               int64            7218             0
# CÓDIGO_ÓRGANO_SUPERIOR              object            7218             0
# NOMBRE_ÓRGANO_SUPERIOR              object            7218             0
# CÓDIGO_ÓRGANO                       object            7218             0
# NOMBRE_ÓRGANO                       object            7218             0
# CÓDIGO_UNIDAD_GESTORA               object            7218             0
# NOMBRE_UNIDAD_GESTORA               object            7218             0
# CATEGORÍA_ECONÓMICA                 object            7218             0
# ORIGEN_INGRESO                      object            7218             0
# TIPO_INGRESO                        object            7218             0
# DETALLE                             object            7218             0
# ...

# %%
df_total_anos[df_total_anos.VALOR_PREVISTO_ACTUALIZADO<0].sort_values('VALOR_PREVISTO_ACTUALIZADO')
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 263269                   55162                  25000
# 258877                   50770                  25000
# 213417                    5310                  22000
# 213299                    5192                  22000
# 213293                    5186                  22000
# 258641                   50534                  25000
#
#                                NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 263269                         Ministério da Economia         25000
# 258877                         Ministério da Economia         25000
# 213417  Ministério da Agricultura, Pecuária e Abastec         20129
# 213299  Ministério da Agricultura, Pecuária e Abastec         20129
# 213293  Ministério da Agricultura, Pecuária e Abastec         20129
# 258641                         Ministério da Economia         25000
#
#                                             NOMBRE_ÓRGANO  \
# ...

# %%
df_total_anos[df_total_anos.VALOR_PREVISTO_ACTUALIZADO==39057100.00].sort_values('VALOR_PREVISTO_ACTUALIZADO', ascending =False)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 213278                    5171                  22000
# 216502                    8395                  22000
#
#                                NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 213278  Ministério da Agricultura, Pecuária e Abastec         20129
# 216502  Ministério da Agricultura, Pecuária e Abastec         49001
#
#                                             NOMBRE_ÓRGANO  \
# 213278  Secretaria Especial de Agricultura Familiar e ...
# 216502               Fundo de Terras e da Reforma Agrária
#
#        CÓDIGO_UNIDAD_GESTORA                         NOMBRE_UNIDAD_GESTORA  \
# 213278                110690  SEC.ESPEC.DE AGRIC.FAMIL.E DO DESENV.AGRARIO
# 216502                490003                             CREDITO FUNDIARIO
#
#         CATEGORÍA_ECONÓMICA               ORIGEN_INGRESO  \
# 213278  Receitas de Capital  Amortizações de Empréstimos
# 216502  Receitas de Capital  Amortizações de Empréstimos
#
# ...

# %%
df_valor_previsto_negativo = df_total_anos[df_total_anos.VALOR_PREVISTO_ACTUALIZADO<0]

# %%
df_valor_previsto_negativo
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 213293                    5186                  22000
# 213299                    5192                  22000
# 213417                    5310                  22000
# 258641                   50534                  25000
# 258877                   50770                  25000
# 263269                   55162                  25000
#
#                                NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 213293  Ministério da Agricultura, Pecuária e Abastec         20129
# 213299  Ministério da Agricultura, Pecuária e Abastec         20129
# 213417  Ministério da Agricultura, Pecuária e Abastec         20129
# 258641                         Ministério da Economia         25000
# 258877                         Ministério da Economia         25000
# 263269                         Ministério da Economia         25000
#
#                                             NOMBRE_ÓRGANO  \
# ...

# %%
df_valor_previsto_negativo["Apunte_duplicado"] = df_valor_previsto_negativo['VALOR_PREVISTO_ACTUALIZADO'].apply(lambda x: 'duplicado en positivo' if -x in list(df_total_anos.VALOR_PREVISTO_ACTUALIZADO) else 'no duplicado')

# %%
df_valor_previsto_negativo
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 213293                    5186                  22000
# 213299                    5192                  22000
# 213417                    5310                  22000
# 258641                   50534                  25000
# 258877                   50770                  25000
# 263269                   55162                  25000
#
#                                NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 213293  Ministério da Agricultura, Pecuária e Abastec         20129
# 213299  Ministério da Agricultura, Pecuária e Abastec         20129
# 213417  Ministério da Agricultura, Pecuária e Abastec         20129
# 258641                         Ministério da Economia         25000
# 258877                         Ministério da Economia         25000
# 263269                         Ministério da Economia         25000
#
#                                             NOMBRE_ÓRGANO  \
# ...

# %%
df_valor_previsto_negativo.Apunte_duplicado.value_counts()
# Out:
# Apunte_duplicado
# duplicado en positivo    6
# Name: count, dtype: int64

# %%
df_valor_registrado_negativo = df_total_anos[df_total_anos.VALOR_REGISTRADO<0]
df_valor_registrado_negativo
# Out:
#          INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 50643                     37069                  25000
# 50647                     37073                  25000
# 50800                     37226                  25000
# 50804                     37230                  25000
# 50805                     37231                  25000
# ...                         ...                    ...
# 949202                    57496                  25000
# 949416                    57710                  25000
# 949428                    57722                  25000
# 1025474                  133768                  54000
# 1025476                  133770                  54000
#
#          NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 50643    Ministério da Economia         25000
# 50647    Ministério da Economia         25000
# 50800    Ministério da Economia         25000
# 50804    Ministério da Economia         25000
# 50805    Ministério da Economia         25000
# ...

# %%
#df_valor_registrado_negativo["Apunte_duplicado"] = df_valor_registrado_negativo['VALOR_REGISTRADO'].apply(lambda x: 'duplicado en positivo' if -x in list(df_total_anos.VALOR_REGISTRADO) else 'no duplicado')

# %%
#df_valor_registrado_negativo.Apunte_duplicado.value_counts()

# %% [markdown]
# Incluyo una imagen del código anterior porque tarda mucho en cargar:
#
#
# ![image.png](attachment:image.png)

# %%
df_valor_registrado_negativo.VALOR_REGISTRADO.sum()
# Out:
# np.float64(-1588463418086.3901)

# %%
df_valor_registrado_positivo = df_total_anos[df_total_anos.VALOR_REGISTRADO>0]
df_valor_registrado_positivo.VALOR_REGISTRADO.sum()
# Out:
# np.float64(6969150082855.92)

# %%
df_total_anos.VALOR_REGISTRADO.sum()
# Out:
# np.float64(5380686664769.532)

# %%
df_valor_realizado_negativo = df_total_anos[df_total_anos.VALOR_REALIZADO<0]
df_valor_realizado_negativo
# Out:
#          INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 53                           53                  22000
# 78                           78                  22000
# 81                           81                  22000
# 135                         135                  22000
# 543                         543                  52000
# ...                         ...                    ...
# 1025368                  133662                  54000
# 1025515                  133809                  54000
# 1025519                  133813                  54000
# 1025561                  133855                  54000
# 1025795                  134089                  54000
#
#                                 NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 53       Ministério da Agricultura, Pecuária e Abastec         22211
# 78       Ministério da Agricultura, Pecuária e Abastec         22211
# 81       Ministério da Agricultura, Pecuária e Abastec         22000
# ...

# %%
#df_valor_realizado_negativo["Apunte_duplicado"] = df_valor_realizado_negativo['VALOR_REALIZADO'].apply(lambda x: 'duplicado en positivo' if -x in list(df_total_anos.VALOR_REALIZADO) else 'no duplicado')

# %%
#df_valor_realizado_negativo

# %%
#df_valor_realizado_negativo.Apunte_duplicado.value_counts()

# %% [markdown]
# Incluyo una imagen del código anterior porque tarda mucho en cargar:
#
#
# ![image.png](attachment:image.png)

# %%
df_valor_realizado_negativo.VALOR_REALIZADO.sum()
# Out:
# np.float64(-900727617952.05)

# %%
df_valor_realizado_positivo = df_total_anos[df_total_anos.VALOR_REALIZADO>0]
df_valor_realizado_positivo.VALOR_REALIZADO.sum()
# Out:
# np.float64(26538110053398.04)

# %%
df_total_anos.VALOR_REALIZADO.sum()
# Out:
# np.float64(25637382435446.004)

# %%
df_total_anos.columns
# Out:
# Index(['INDICE_DF_AÑO_ORIGINAL', 'CÓDIGO_ÓRGANO_SUPERIOR',
#        'NOMBRE_ÓRGANO_SUPERIOR', 'CÓDIGO_ÓRGANO', 'NOMBRE_ÓRGANO',
#        'CÓDIGO_UNIDAD_GESTORA', 'NOMBRE_UNIDAD_GESTORA', 'CATEGORÍA_ECONÓMICA',
#        'ORIGEN_INGRESO', 'TIPO_INGRESO', 'DETALLE',
#        'VALOR_PREVISTO_ACTUALIZADO', 'VALOR_REGISTRADO', 'VALOR_REALIZADO',
#        'PORCENTAJE_REALIZADO', 'FECHA_REGISTRO', 'AÑO_EJERCICIO'],
#       dtype='object')

# %% [markdown]
# ### Creación nuevas columnas de los valores numéricos para sustituir los 0 por nulos:

# %%
df_total_anos["VALOR_PREVISTO_ACTUALIZADO_SIN_0"]  = df_total_anos["VALOR_PREVISTO_ACTUALIZADO"].apply(se.cambiar0pornpnan)
df_total_anos["VALOR_REGISTRADO_SIN_0"]  = df_total_anos["VALOR_REGISTRADO"].apply(se.cambiar0pornpnan)
df_total_anos["VALOR_REALIZADO_SIN_0"] = df_total_anos["VALOR_REALIZADO"].apply(se.cambiar0pornpnan)

# %%
se.reporte(df_total_anos)
# Out:
# La tabla tiene 1026299 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64         1026299
# CÓDIGO_ÓRGANO_SUPERIOR                    object         1026299
# NOMBRE_ÓRGANO_SUPERIOR                    object         1026299
# CÓDIGO_ÓRGANO                             object         1026299
# NOMBRE_ÓRGANO                             object         1026299
# CÓDIGO_UNIDAD_GESTORA                     object         1026299
# NOMBRE_UNIDAD_GESTORA                     object         1026299
# CATEGORÍA_ECONÓMICA                       object         1026299
# ORIGEN_INGRESO                            object         1026299
# TIPO_INGRESO                              object         1026299
# DETALLE                                   object         1026299
# VALOR_PREVISTO_ACTUALIZADO               float64         1026299
# ...

# %% [markdown]
# El valor previsto actualizado tiene un 98,07% de valores con 0 o nulos, el valor registrado tiene un 99,30% de valores con 0 o nulos y el valor realizado tiene un 2,05% de valores con 0 o nulos

# %%
se.analisis_descriptivos_numéricas(df_total_anos)
# Out:
# Las columnas no categóricas son Index(['INDICE_DF_AÑO_ORIGINAL', 'VALOR_PREVISTO_ACTUALIZADO',
#        'VALOR_REGISTRADO', 'VALOR_REALIZADO', 'PORCENTAJE_REALIZADO',
#        'FECHA_REGISTRO', 'AÑO_EJERCICIO', 'VALOR_PREVISTO_ACTUALIZADO_SIN_0',
#        'VALOR_REGISTRADO_SIN_0', 'VALOR_REALIZADO_SIN_0'],
#       dtype='object')
# Algunos ejemplos de filas son:
#         INDICE_DF_AÑO_ORIGINAL  VALOR_PREVISTO_ACTUALIZADO  VALOR_REGISTRADO  \
# 66877                    53303                        0.00              0.00
# 869198                  119840                        0.00              0.00
# 636747                   64217                        0.00              0.00
# 889490                  140132                        0.00              0.00
# 941610                   49904                        0.00              0.00
#
#         VALOR_REALIZADO  PORCENTAJE_REALIZADO FECHA_REGISTRO  AÑO_EJERCICIO  \
# ...

# %% [markdown]
# De esta forma se puede ver más claramente los tramos entre los que se mueven estos valores

# %% [markdown]
# ## Análisis posibles duplicados variables categóricas

# %% [markdown]
# ### a.  Nombre órgano superior

# %%
df_total_anos['CODIGO_NOMBRE_ORGANO_SUPERIOR'] = df_total_anos.CÓDIGO_ÓRGANO_SUPERIOR+ '|' + df_total_anos.NOMBRE_ÓRGANO_SUPERIOR

# %%
df_total_anos
# Out:
#          INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 0                             0                  63000
# 1                             1                  63000
# 2                             2                  63000
# 3                             3                  63000
# 4                             4                  63000
# ...                         ...                    ...
# 1026294                  134588                  20000
# 1026295                  134589                  20000
# 1026296                  134590                  20000
# 1026297                  134591                  20000
# 1026298                  134592                  20000
#
#            NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 0        Advocacia-Geral da União         63000
# 1        Advocacia-Geral da União         63000
# 2        Advocacia-Geral da União         63000
# 3        Advocacia-Geral da União         63000
# 4        Advocacia-Geral da União         63000
# ...

# %%
df_total_anos['CODIGO_NOMBRE_ORGANO'] = df_total_anos.CÓDIGO_ÓRGANO+ '|' + df_total_anos.NOMBRE_ÓRGANO

# %%
df_total_anos
# Out:
#          INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 0                             0                  63000
# 1                             1                  63000
# 2                             2                  63000
# 3                             3                  63000
# 4                             4                  63000
# ...                         ...                    ...
# 1026294                  134588                  20000
# 1026295                  134589                  20000
# 1026296                  134590                  20000
# 1026297                  134591                  20000
# 1026298                  134592                  20000
#
#            NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 0        Advocacia-Geral da União         63000
# 1        Advocacia-Geral da União         63000
# 2        Advocacia-Geral da União         63000
# 3        Advocacia-Geral da União         63000
# 4        Advocacia-Geral da União         63000
# ...

# %%
df_contador_codigos_nombre_organos_total = df_total_anos['CODIGO_NOMBRE_ORGANO'].value_counts().reset_index()
df_contador_codigos_nombre_organos_total
# Out:
#                                   CODIGO_NOMBRE_ORGANO   count
# 0    25000|Ministério da Economia - Unidades com ví...  119811
# 1                              52904|Fundo do Exército   25559
# 2               52132|Comando da Marinha - Fundo Naval   23734
# 3                      34902|Fundo Nacional de Cultura   15955
# 4    20701|Instituto Brasileiro do Meio Ambiente e ...   13745
# ..                                                 ...     ...
# 286                36208|Hospital Cristo Redentor S.A.       2
# 287       53205|Agência de Desenvolvimento da Amazônia       2
# 288  29201|Departamento Nacional de Estradas de Rod...       1
# 289    20605|Companhia de Desenvolvimento de Barcarena       1
# 290                         36209|Hospital Fêmina S.A.       1
#
# [291 rows x 2 columns]

# %%
df_contador_codigos_nombre_organos_total["nombre"] =df_contador_codigos_nombre_organos_total.CODIGO_NOMBRE_ORGANO.str.split("|",expand=True)[1]
df_contador_codigos_nombre_organos_total
# Out:
#                                   CODIGO_NOMBRE_ORGANO   count  \
# 0    25000|Ministério da Economia - Unidades com ví...  119811
# 1                              52904|Fundo do Exército   25559
# 2               52132|Comando da Marinha - Fundo Naval   23734
# 3                      34902|Fundo Nacional de Cultura   15955
# 4    20701|Instituto Brasileiro do Meio Ambiente e ...   13745
# ..                                                 ...     ...
# 286                36208|Hospital Cristo Redentor S.A.       2
# 287       53205|Agência de Desenvolvimento da Amazônia       2
# 288  29201|Departamento Nacional de Estradas de Rod...       1
# 289    20605|Companhia de Desenvolvimento de Barcarena       1
# 290                         36209|Hospital Fêmina S.A.       1
#
#                                                 nombre
# 0    Ministério da Economia - Unidades com vínculo ...
# 1                                    Fundo do Exército
# ...

# %%
df_contador_nombres = df_contador_codigos_nombre_organos_total['nombre'].value_counts().reset_index()

# %%
df_contador_nombres[df_contador_nombres['count'] >1]
# Out:
#                                           nombre  count
# 0                      Fundo Nacional Antidrogas      2
# 1    Agência Nacional de Transportes Aquaviários      2
# 2  Fundo Nacional para a Criança e o Adolescente      2
# 3                        Fundo Nacional do Idoso      2

# %%
df_total_anos[df_total_anos.NOMBRE_ÓRGANO == 'Fundo Nacional Antidrogas'].CODIGO_NOMBRE_ORGANO.value_counts()
# Out:
# CODIGO_NOMBRE_ORGANO
# 30912|Fundo Nacional Antidrogas    7596
# 20117|Fundo Nacional Antidrogas      20
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_ÓRGANO == 'Agência Nacional de Transportes Aquaviários'].CODIGO_NOMBRE_ORGANO.value_counts()
# Out:
# CODIGO_NOMBRE_ORGANO
# 68201|Agência Nacional de Transportes Aquaviários    2178
# 39251|Agência Nacional de Transportes Aquaviários       5
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_ÓRGANO == 'Fundo Nacional para a Criança e o Adolescente'].CODIGO_NOMBRE_ORGANO.value_counts()
# Out:
# CODIGO_NOMBRE_ORGANO
# 30913|Fundo Nacional para a Criança e o Adolescente    746
# 64901|Fundo Nacional para a Criança e o Adolescente    184
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_ÓRGANO == 'Fundo Nacional do Idoso'].CODIGO_NOMBRE_ORGANO.value_counts()
# Out:
# CODIGO_NOMBRE_ORGANO
# 30914|Fundo Nacional do Idoso    230
# 64902|Fundo Nacional do Idoso    101
# Name: count, dtype: int64

# %% [markdown]
# ### b. Nombre unidad gestora

# %%
df_total_anos['CODIGO_NOMBRE_UNIDAD_GESTORA'] = df_total_anos.CÓDIGO_UNIDAD_GESTORA+ '|' + df_total_anos.NOMBRE_UNIDAD_GESTORA

# %%
df_contador_codigos_nombre_unidad_gestora_total = df_total_anos['CODIGO_NOMBRE_UNIDAD_GESTORA'].value_counts().reset_index()
df_contador_codigos_nombre_unidad_gestora_total
# Out:
#                           CODIGO_NOMBRE_UNIDAD_GESTORA   count
# 0       170013|SETORIAL ORCAMENTARIA E FINANCEIRA / ME  108481
# 1                             167086|FUNDO DO EXERCITO   25469
# 2    673001|DIRETORIA DE FINANCAS-SISTEMA PARA O PA...   19196
# 3    193034|IBAMA - INST.BRASILEIRO MEIO AMBIENTE/M...   13698
# 4                              135037|EMBRAPA-SETORIAL   13641
# ..                                                 ...     ...
# 359      533001|AGENCIA DE DESENVOLVIMENTO DA AMAZONIA       2
# 360                         366002|HOSPITAL FEMINA S/A       1
# 361  200337|COORDENACAO DE ORCAMENTO E FINANCAS - C...       1
# 362   195008|COMPANHIA DE DESENVOLVIMENTO DE BARCARENA       1
# 363  273087|DEPARTAMENTO NAC. ESTRADAS E RODAGEM-EX...       1
#
# [364 rows x 2 columns]

# %%
df_contador_codigos_nombre_unidad_gestora_total["nombre"] =df_contador_codigos_nombre_unidad_gestora_total.CODIGO_NOMBRE_UNIDAD_GESTORA.str.split("|",expand=True)[1]
df_contador_codigos_nombre_unidad_gestora_total
# Out:
#                           CODIGO_NOMBRE_UNIDAD_GESTORA   count  \
# 0       170013|SETORIAL ORCAMENTARIA E FINANCEIRA / ME  108481
# 1                             167086|FUNDO DO EXERCITO   25469
# 2    673001|DIRETORIA DE FINANCAS-SISTEMA PARA O PA...   19196
# 3    193034|IBAMA - INST.BRASILEIRO MEIO AMBIENTE/M...   13698
# 4                              135037|EMBRAPA-SETORIAL   13641
# ..                                                 ...     ...
# 359      533001|AGENCIA DE DESENVOLVIMENTO DA AMAZONIA       2
# 360                         366002|HOSPITAL FEMINA S/A       1
# 361  200337|COORDENACAO DE ORCAMENTO E FINANCAS - C...       1
# 362   195008|COMPANHIA DE DESENVOLVIMENTO DE BARCARENA       1
# 363  273087|DEPARTAMENTO NAC. ESTRADAS E RODAGEM-EX...       1
#
#                                             nombre
# 0          SETORIAL ORCAMENTARIA E FINANCEIRA / ME
# 1                                FUNDO DO EXERCITO
# 2     DIRETORIA DE FINANCAS-SISTEMA PARA O PAIS/MM
# ...

# %%
df_contador_nombres_unidad_gestora = df_contador_codigos_nombre_unidad_gestora_total['nombre'].value_counts().reset_index()

# %%
df_contador_nombres_unidad_gestora[df_contador_nombres_unidad_gestora['count'] >1]
# Out:
#                                           nombre  count
# 0       COORDENACAO-GERAL DE RECURSOS LOGISTICOS      2
# 1                      FUNDO NACIONAL ANTIDROGAS      2
# 2      COORDENACAO-GERAL DE ORCAMENTO E FINANCAS      2
# 3    AGENCIA NACIONAL DE TRANSPORTES AQUAVIARIOS      2
# 4   DIRETORIA DE FINANCAS-SISTEMA PARA O PAIS/MM      2
# 5  FUNDO NACIONAL PARA A CRIANCA E O ADOLESCENTE      2
# 6    SETORIAL PROG.ORCAMENTARIA E FINANCEIRA-SFB      2
# 7                        FUNDO NACIONAL DO IDOSO      2

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'COORDENACAO-GERAL DE RECURSOS LOGISTICOS'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 410003|COORDENACAO-GERAL DE RECURSOS LOGISTICOS    4
# 240101|COORDENACAO-GERAL DE RECURSOS LOGISTICOS    3
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'FUNDO NACIONAL ANTIDROGAS'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 200246|FUNDO NACIONAL ANTIDROGAS    7596
# 110246|FUNDO NACIONAL ANTIDROGAS      20
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'COORDENACAO-GERAL DE ORCAMENTO E FINANCAS'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 240102|COORDENACAO-GERAL DE ORCAMENTO E FINANCAS    5532
# 410002|COORDENACAO-GERAL DE ORCAMENTO E FINANCAS     308
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'AGENCIA NACIONAL DE TRANSPORTES AQUAVIARIOS'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 682010|AGENCIA NACIONAL DE TRANSPORTES AQUAVIARIOS    2178
# 393002|AGENCIA NACIONAL DE TRANSPORTES AQUAVIARIOS       5
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'DIRETORIA DE FINANCAS-SISTEMA PARA O PAIS/MM'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 673001|DIRETORIA DE FINANCAS-SISTEMA PARA O PAIS/MM    19196
# 873001|DIRETORIA DE FINANCAS-SISTEMA PARA O PAIS/MM     4336
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'FUNDO NACIONAL PARA A CRIANCA E O ADOLESCENTE'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 307001|FUNDO NACIONAL PARA A CRIANCA E O ADOLESCENTE    746
# 110244|FUNDO NACIONAL PARA A CRIANCA E O ADOLESCENTE    168
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'SETORIAL PROG.ORCAMENTARIA E FINANCEIRA-SFB'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 440088|SETORIAL PROG.ORCAMENTARIA E FINANCEIRA-SFB    609
# 130214|SETORIAL PROG.ORCAMENTARIA E FINANCEIRA-SFB      7
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.NOMBRE_UNIDAD_GESTORA == 'FUNDO NACIONAL DO IDOSO'].CODIGO_NOMBRE_UNIDAD_GESTORA.value_counts()
# Out:
# CODIGO_NOMBRE_UNIDAD_GESTORA
# 307002|FUNDO NACIONAL DO IDOSO    230
# 207001|FUNDO NACIONAL DO IDOSO     89
# Name: count, dtype: int64

# %% [markdown]
# ### c. Categoría económica

# %% [markdown]
# Según los datos iniciales, la categoría económica solo debía tener dos opciones (Receitas Correntes y Receitas de capital), no obstante, esta columna tiene más valores:

# %%
df_total_anos.CATEGORÍA_ECONÓMICA.value_counts()
# Out:
# CATEGORÍA_ECONÓMICA
# Receitas Correntes                           979596
# Receitas de Capital                           30116
# Receitas Correntes - intra-orçamentárias      16235
# Sem informação                                  257
# Receitas de Capital - intra-orçamentárias        95
# Name: count, dtype: int64

# %% [markdown]
# intra-orçamentárias significa, intraprespuestarias, es decir dentro de presupuesto, por lo tanto, entendiendo que todos los ingresos están dentro de presupuestos, elimino la parte intra-orçamentárias de la categoría y creo una nueva columna para agruparlo

# %%
df_total_anos["CATEGORIA_ECONÓMICA_AGRUPADA"] = df_total_anos.CATEGORÍA_ECONÓMICA.str.split("-",expand=True)[0].str.rstrip()

# %%
df_total_anos.CATEGORIA_ECONÓMICA_AGRUPADA.value_counts()
# Out:
# CATEGORIA_ECONÓMICA_AGRUPADA
# Receitas Correntes     995831
# Receitas de Capital     30211
# Sem informação            257
# Name: count, dtype: int64

# %% [markdown]
# Analizo la categoría Sem informação para ver si puedo averiguar el tipo de ingreso:

# %%
df_categoria_economica_sin_información = df_total_anos[df_total_anos.CATEGORIA_ECONÓMICA_AGRUPADA == 'Sem informação' ]
df_categoria_economica_sin_información
# Out:
#          INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 925                         925                  25000
# 5398                        900                  25000
# 244838                    36731                  25000
# 244840                    36733                  25000
# 244854                    36747                  25000
# ...                         ...                    ...
# 1001435                  109729                  36000
# 1001826                  110120                  36000
# 1004617                  112911                  36000
# 1005028                  113322                  36000
# 1005029                  113323                  36000
#
#          NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 925      Ministério da Economia         25203
# 5398     Ministério da Economia         25203
# 244838   Ministério da Economia         25000
# 244840   Ministério da Economia         25000
# 244854   Ministério da Economia         25000
# ...

# %%
se.reporte(df_categoria_economica_sin_información)
# Out:
# La tabla tiene 257 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64             257
# CÓDIGO_ÓRGANO_SUPERIOR                    object             257
# NOMBRE_ÓRGANO_SUPERIOR                    object             257
# CÓDIGO_ÓRGANO                             object             257
# NOMBRE_ÓRGANO                             object             257
# CÓDIGO_UNIDAD_GESTORA                     object             257
# NOMBRE_UNIDAD_GESTORA                     object             257
# CATEGORÍA_ECONÓMICA                       object             257
# ORIGEN_INGRESO                            object             257
# TIPO_INGRESO                              object             257
# DETALLE                                   object             257
# VALOR_PREVISTO_ACTUALIZADO               float64             257
# ...

# %%
df_importes_agrupación_categoria_economica_dif_metricas=df_total_anos.groupby('CATEGORIA_ECONÓMICA_AGRUPADA')[['VALOR_PREVISTO_ACTUALIZADO',
       'VALOR_REGISTRADO', 'VALOR_REALIZADO']].agg(["mean", "sum", "count"])

df_importes_agrupación_categoria_economica_dif_metricas["VALOR_REALIZADO/VALOR_PREVISTO_ACTUALIZADO"] = (df_importes_agrupación_categoria_economica_dif_metricas.iloc[:,7]/df_importes_agrupación_categoria_economica_dif_metricas.iloc[:,1])*100

df_importes_agrupación_categoria_economica_dif_metricas['Peso_categoria']=df_importes_agrupación_categoria_economica_dif_metricas.iloc[:,8]/df_total_anos.shape[0]*100
df_importes_agrupación_categoria_economica_dif_metricas['Peso total valor realizado']=df_importes_agrupación_categoria_economica_dif_metricas.iloc[:,7]/df_total_anos.VALOR_REALIZADO.sum()
df_importes_agrupación_categoria_economica_dif_metricas
# Out:
#                              VALOR_PREVISTO_ACTUALIZADO                    \
#                                                    mean               sum
# CATEGORIA_ECONÓMICA_AGRUPADA
# Receitas Correntes                          13898956.72 13841011969125.14
# Receitas de Capital                        479843826.51 14496561842743.59
# Sem informação                                     0.00              0.00
#
#                                      VALOR_REGISTRADO                   \
#                                count             mean              sum
# CATEGORIA_ECONÓMICA_AGRUPADA
# Receitas Correntes            995831       5400384.71 5377870503243.72
# Receitas de Capital            30211           126.24       3813949.42
# Sem informação                   257      10942986.68    2812347576.39
#
#                                      VALOR_REALIZADO                    \
#                                count            mean               sum
# CATEGORIA_ECONÓMICA_AGRUPADA
# ...

# %% [markdown]
# ### d. Análisis origen ingreso si está correctamente categorizado, tipo ingreso y detalle

# %%
print(f'Las categorias de recetas corrientes y recetas de capital son:')
df_categorias_recetas_corrientes_y_capital= df_diccionario_datos[df_diccionario_datos.DESCRIÇÃO.notnull()][df_diccionario_datos['Unnamed: 3'].notnull()]
df_categorias_recetas_corrientes_y_capital[['DESCRIÇÃO','Unnamed: 3']]
# Out:
# Las categorias de recetas corrientes y recetas de capital son:
#                       DESCRIÇÃO                                   Unnamed: 3
# 21   Para Receitas Correntes:                   Para Receitas Correntes:
# 22                           1.  Impostos, Taxas e Contribuições de Melhoria
# 23                           2.                                Contribuições
# 24                           3.                          Receita Patrimonial
# 25                           4.                         Receita Agropecuária
# 26                           5.                           Receita Industrial
# 27                           6.                          Receita de Serviços
# 28                           7.                     Transferências Correntes
# 30  Para Receitas de Capital:                  Para Receitas de Capital:
# 31                           1.                         Operações de Crédito
# ...

# %% [markdown]
# Por tanto, Receitas correntes solo debe tener:
# 1.	Impostos, Taxas e Contribuições de Melhoria
# 2.	Contribuições
# 3.	Receita Patrimonial
# 4.	Receita Agropecuária
# 5.	Receita Industrial
# 6.	Receita de Serviços
# 7.	Transferências Correntes

# %%
df_total_anos[df_total_anos.CATEGORIA_ECONÓMICA_AGRUPADA == 'Receitas Correntes'].ORIGEN_INGRESO.value_counts()
# Out:
# ORIGEN_INGRESO
# Outras Receitas Correntes                      322907
# Receita de Serviços                            322319
# Receita Patrimonial                            163171
# Impostos, Taxas e Contribuições de Melhoria     78340
# Contribuições                                   66781
# Receita Industrial                              18857
# Receita Agropecuária                            13642
# Transferências Correntes                         6385
# Receitas Correntes - a classificar               3429
# Name: count, dtype: int64

# %% [markdown]
# Todas tienen una categoría correcta.
#
# Analizo las Receitas Correntes - a clasificar

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receitas Correntes - a classificar'].sample(5)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  NOMBRE_ÓRGANO_SUPERIOR  \
# 39859                    26285                  52000    Ministério da Defesa
# 442820                   44234                  25000  Ministério da Economia
# 419454                   20868                  52000    Ministério da Defesa
# 256844                   48737                  25000  Ministério da Economia
# 169093                  155519                  36000     Ministério da Saúde
#
#        CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 39859          52904                                  Fundo do Exército
# 442820         22500  Companhia de Entrepostos e Armazéns Gerais de ...
# 419454         52121                                Comando do Exército
# 256844         22500  Companhia de Entrepostos e Armazéns Gerais de ...
# 169093         36201                              Fundação Oswaldo Cruz
#
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receitas Correntes - a classificar'])
# Out:
# La tabla tiene 3429 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64            3429
# CÓDIGO_ÓRGANO_SUPERIOR                    object            3429
# NOMBRE_ÓRGANO_SUPERIOR                    object            3429
# CÓDIGO_ÓRGANO                             object            3429
# NOMBRE_ÓRGANO                             object            3429
# CÓDIGO_UNIDAD_GESTORA                     object            3429
# NOMBRE_UNIDAD_GESTORA                     object            3429
# CATEGORÍA_ECONÓMICA                       object            3429
# ORIGEN_INGRESO                            object            3429
# TIPO_INGRESO                              object            3429
# DETALLE                                   object            3429
# VALOR_PREVISTO_ACTUALIZADO               float64            3429
# ...

# %% [markdown]
# En detalle hay 2 tipos de detalles. Analizo los 2 que aparecen por si puede ayudarme a saber qué tipo de categoría económica es:

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receitas Correntes - a classificar'].DETALLE.value_counts()
# Out:
# DETALLE
# Receitas Correntes - a classificar    3413
# RECEITAS CORRENTES A CLASSIFICAR        16
# Name: count, dtype: int64

# %% [markdown]
# Parece que en la columna DETALLE está duplicada la categoría, sustituyo RECEITAS CORRENTES A CLASSIFICAR por Receitas Correntes - a classificar

# %%
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('RECEITAS CORRENTES A CLASSIFICAR', 'Receitas Correntes - a classificar')

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receitas Correntes - a classificar'].DETALLE.value_counts()
# Out:
# DETALLE
# Receitas Correntes - a classificar    3429
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receitas Correntes - a classificar'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Receitas Correntes - a classificar    3429
# Name: count, dtype: int64

# %% [markdown]
# Analizo Transferências Correntes

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências Correntes'].sample(5)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  NOMBRE_ÓRGANO_SUPERIOR  \
# 303883                   95776                  26000  Ministério da Educação
# 775917                   26559                  52000    Ministério da Defesa
# 334635                  126528                  26000  Ministério da Educação
# 265566                   57459                  25000  Ministério da Economia
# 983753                   92047                  26000  Ministério da Educação
#
#        CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 303883         26278           Fundação Universidade Federal de Pelotas
# 775917         52222                                    Fundação Osório
# 334635         26432                        Instituto Federal do Paraná
# 265566         25201  Banco Central do Brasil - Orçamento Fiscal e S...
# 983753         26294               Hospital de Clínicas de Porto Alegre
#
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências Correntes'])
# Out:
# La tabla tiene 6385 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64            6385
# CÓDIGO_ÓRGANO_SUPERIOR                    object            6385
# NOMBRE_ÓRGANO_SUPERIOR                    object            6385
# CÓDIGO_ÓRGANO                             object            6385
# NOMBRE_ÓRGANO                             object            6385
# CÓDIGO_UNIDAD_GESTORA                     object            6385
# NOMBRE_UNIDAD_GESTORA                     object            6385
# CATEGORÍA_ECONÓMICA                       object            6385
# ORIGEN_INGRESO                            object            6385
# TIPO_INGRESO                              object            6385
# DETALLE                                   object            6385
# VALOR_PREVISTO_ACTUALIZADO               float64            6385
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências Correntes'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências de Instituições Privadas          1825
# Transferências dos Estados e do Distrito Fede    1230
# Transferências Correntes                         1008
# Transferências de Pessoas Físicas                 837
# Transferências dos Municípios e de suas Entid     550
# Transferências Provenientes de Depósito Não I     429
# Transferências de Convênios                       295
# Transferências da União e de suas Entidades       193
# Transferências de Outras Instituições Pública      18
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências Correntes'].DETALLE.value_counts()
# Out:
# DETALLE
# TRANSFERENCIAS DE INSTITUICOES PRIVADAS-PRINC    2188
# TRANSF.DOS ESTADOS,DF E SUAS ENTIDADES-PRINC.    1387
# TRANSFERENCIAS DE PESSOAS FISICAS-PRINCIPAL       989
# TRANSF.DOS MUNICIPIOS E SUAS ENTIDADES-PRINC.     574
# TRANSF.PROVENIENTES DEP.NAO IDENTIFIC.-PRINC.     568
# TRANSFER.DA UNIAO E DE SUAS ENTIDADES-PRINC.      242
# TRANSF.DOS ESTADOS DF E SUAS ENTIDADES             94
# TRANSFERENCIAS CONVENIOS DA UNIAO E ENTIDADES      60
# TRANSFER. CONVENIOS DE INSTITUICOES PRIVADAS       60
# TRANSF.CONV.DOS MUNICIPIOS E SUAS ENTIDADEDES      49
# TRANSFERENCIAS DO EXTERIOR-PRINCIPAL               37
# Transferências dos Municípios e de suas Entid      31
# Transferências de Instituições Privadas            20
# TRANSFERENCIAS DE INSTITUICOES PRIVADAS            20
# TRANSF.DOS EST.,DF E SUAS ENTIDADES-MUL.JUR.       12
# Transferências de Outras Instituições Pública      11
# TRANSFERENCIAS A CONSORCIOS PUBLICOS                8
# ...

# %% [markdown]
# Transferências de Instituições Privadas está duplicada con TRANSFERENCIAS DE INSTITUICOES PRIVADAS

# %%
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('Transferências de Instituições Privadas', 'TRANSFERENCIAS DE INSTITUICOES PRIVADAS')

# %% [markdown]
# Transferências de Outras Instituições Pública está duplicada con TRANSF.DE OUTRAS INSTITUICOES PUBLICAS-PRINC

# %%
df_total_anos[ df_total_anos.DETALLE=='Transferências de Outras Instituições Pública']
# Out:
#       INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 426                      426                  52000
# 2082                    2082                  26000
# 2083                    2083                  26000
# 3789                    3789                  57000
# 3790                    3790                  57000
# 4912                     414                  52000
# 6465                    1967                  26000
# 6466                    1968                  26000
# 6467                    1969                  26000
# 8308                    3810                  57000
# 8309                    3811                  57000
#
#                              NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 426                            Ministério da Defesa         52222
# 2082                         Ministério da Educação         26233
# 2083                         Ministério da Educação         26261
# 3789  Ministério das Mulheres, Igualdade Racial, da         64902
# ...

# %%
df_total_anos[ df_total_anos.DETALLE=='TRANSF.DE OUTRAS INSTITUICOES PUBLICAS-PRINC.']
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 165486                  151912                  30000
# 194106                  180532                  53000
# 195256                  181682                  53000
# 211156                    3049                  22000
# 300335                   92228                  26000
# 386524                  178417                  53000
# 406721                    8135                  55000
# 406732                    8146                  55000
#
#                                NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 165486      Ministério da Justiça e Segurança Pública         30108
# 194106         Ministério do Desenvolvimento Regional         29214
# 195256         Ministério do Desenvolvimento Regional         56902
# 211156  Ministério da Agricultura, Pecuária e Abastec         22201
# 300335                         Ministério da Educação         26419
# ...

# %%
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('Transferências de Outras Instituições Pública', 'TRANSF.DE OUTRAS INSTITUICOES PUBLICAS-PRINC.')

# %% [markdown]
# Analizo si TRANSF.CONV.DOS MUNICIPIOS E SUAS ENTIDADEDES está duplicado con Transferências dos Municípios e de suas Entid

# %%
df_total_anos[ df_total_anos.DETALLE=='TRANSF.CONV.DOS MUNICIPIOS E SUAS ENTIDADEDES']
# Out:
#        INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  NOMBRE_ÓRGANO_SUPERIOR  \
# 500                       500                  52000    Ministério da Defesa
# 2619                     2619                  26000  Ministério da Educação
# 2620                     2620                  26000  Ministério da Educação
# 2621                     2621                  26000  Ministério da Educação
# 2622                     2622                  26000  Ministério da Educação
# 2623                     2623                  26000  Ministério da Educação
# 2624                     2624                  26000  Ministério da Educação
# 2625                     2625                  26000  Ministério da Educação
# 2627                     2627                  26000  Ministério da Educação
# 2628                     2628                  26000  Ministério da Educação
# 2629                     2629                  26000  Ministério da Educação
# ...

# %%
df_total_anos[ df_total_anos.DETALLE=='Transferências dos Municípios e de suas Entid']
# Out:
#       INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 24                        24                  22000
# 26                        26                  22000
# 236                      236                  24000
# 602                      602                  25000
# 605                      605                  25000
# 1087                    1087                  25000
# 1491                    1491                  26000
# 1505                    1505                  26000
# 1508                    1508                  26000
# 1520                    1520                  26000
# 1524                    1524                  26000
# 1548                    1548                  26000
# 1549                    1549                  26000
# 3575                    3575                  36000
# 3784                    3784                  57000
# 3785                    3785                  57000
# 4234                    4234                  44000
# ...

# %%
df_total_anos[ df_total_anos.TIPO_INGRESO=='Transferências dos Municípios e de suas Entid'].DETALLE.value_counts()
# Out:
# DETALLE
# TRANSF.DOS MUNICIPIOS E SUAS ENTIDADES-PRINC.    586
# Transferências dos Municípios e de suas Entid     33
# TRANSFERENCIAS DE INSTITUICOES PRIVADAS           21
# Name: count, dtype: int64

# %% [markdown]
# TRANSF.DOS MUNICIPIOS E SUAS ENTIDADES-PRINC.  esta duplicado con Transferências dos Municípios e de suas Entid

# %%
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('Transferências dos Municípios e de suas Entid', 'TRANSF.DOS MUNICIPIOS E SUAS ENTIDADES-PRINC.')

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências Correntes'].DETALLE.value_counts()
# Out:
# DETALLE
# TRANSFERENCIAS DE INSTITUICOES PRIVADAS-PRINC    2188
# TRANSF.DOS ESTADOS,DF E SUAS ENTIDADES-PRINC.    1387
# TRANSFERENCIAS DE PESSOAS FISICAS-PRINCIPAL       989
# TRANSF.DOS MUNICIPIOS E SUAS ENTIDADES-PRINC.     605
# TRANSF.PROVENIENTES DEP.NAO IDENTIFIC.-PRINC.     568
# TRANSFER.DA UNIAO E DE SUAS ENTIDADES-PRINC.      242
# TRANSF.DOS ESTADOS DF E SUAS ENTIDADES             94
# TRANSFERENCIAS CONVENIOS DA UNIAO E ENTIDADES      60
# TRANSFER. CONVENIOS DE INSTITUICOES PRIVADAS       60
# TRANSF.CONV.DOS MUNICIPIOS E SUAS ENTIDADEDES      49
# TRANSFERENCIAS DE INSTITUICOES PRIVADAS            40
# TRANSFERENCIAS DO EXTERIOR-PRINCIPAL               37
# TRANSF.DE OUTRAS INSTITUICOES PUBLICAS-PRINC.      16
# TRANSF.DOS EST.,DF E SUAS ENTIDADES-MUL.JUR.       12
# TRANSFERENCIAS A CONSORCIOS PUBLICOS                8
# TRANSFERENCIAS DO EXTERIOR                          6
# PROVENIENTES DE PESSOAS FISICAS                     5
# ...

# %% [markdown]
# Analizo Receita Agropecuária

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Agropecuária'].sample(5)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 823979                   74621                  26000
# 212837                    4730                  22000
# 381187                  173080                  53000
# 820211                   70853                  26000
# 107845                   94271                  26000
#
#                                NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 823979                         Ministério da Educação         26416
# 212837  Ministério da Agricultura, Pecuária e Abastec         22000
# 381187         Ministério do Desenvolvimento Regional         22204
# 820211                         Ministério da Educação         26413
# 107845                         Ministério da Educação         26434
#
#                                             NOMBRE_ÓRGANO  \
# 823979                          Instituto Federal do Pará
# 212837  Ministério da Agricultura, Pecuária e Abasteci...
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Agropecuária'])
# Out:
# La tabla tiene 13642 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64           13642
# CÓDIGO_ÓRGANO_SUPERIOR                    object           13642
# NOMBRE_ÓRGANO_SUPERIOR                    object           13642
# CÓDIGO_ÓRGANO                             object           13642
# NOMBRE_ÓRGANO                             object           13642
# CÓDIGO_UNIDAD_GESTORA                     object           13642
# NOMBRE_UNIDAD_GESTORA                     object           13642
# CATEGORÍA_ECONÓMICA                       object           13642
# ORIGEN_INGRESO                            object           13642
# TIPO_INGRESO                              object           13642
# DETALLE                                   object           13642
# VALOR_PREVISTO_ACTUALIZADO               float64           13642
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Agropecuária'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Receita Agropecuária                      13327
# Receita da produção animal e derivados      147
# Receita da produção vegetal                 144
# Outras receitas agropecuárias                24
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Agropecuária'].DETALLE.value_counts()
# Out:
# DETALLE
# RECEITA AGROPECUÁRIA-PRINCIPAL            9015
# RECEITA AGROPECUARIA-PRINCIPAL            4254
# Receita da produção animal e derivados      99
# Receita da produção vegetal                 98
# RECEITA DA PRODUCAO ANIMAL E DERIVADOS      48
# RECEITA DA PRODUCAO VEGETAL                 46
# RECEITA AGROPECUÁRIA-MULTAS E JUROS         30
# RECEITA AGROPECUARIA-MULTAS E JUROS         28
# Outras receitas agropecuárias               16
# OUTRAS RECEITAS AGROPECUARIAS                8
# Name: count, dtype: int64

# %% [markdown]
# Sustituyo Receita da produção animal e derivados  por RECEITA DA PRODUCAO ANIMAL E DERIVADOS
#
#
# Sustituyo Receita da produção vegetal por RECEITA DA PRODUCAO VEGETAL
#
#
# Sustituyo Outras receitas agropecuárias   por OUTRAS RECEITAS AGROPECUARIAS
#
# Sustituyo AGROPECUÁRIA por AGROPECUARIA

# %%
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('Receita da produção animal e derivados', 'RECEITA DA PRODUCAO ANIMAL E DERIVADOS')
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('Receita da produção vegetal', 'RECEITA DA PRODUCAO VEGETAL')
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('Outras receitas agropecuárias', 'OUTRAS RECEITAS AGROPECUARIAS')
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('AGROPECUÁRIA', 'AGROPECUARIA')

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Agropecuária'].DETALLE.value_counts()
# Out:
# DETALLE
# RECEITA AGROPECUARIA-PRINCIPAL            13269
# RECEITA DA PRODUCAO ANIMAL E DERIVADOS      147
# RECEITA DA PRODUCAO VEGETAL                 144
# RECEITA AGROPECUARIA-MULTAS E JUROS          58
# OUTRAS RECEITAS AGROPECUARIAS                24
# Name: count, dtype: int64

# %% [markdown]
# Analizo Receita Industrial

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Industrial'].sample(5)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 758046                    8688                  24000
# 656884                   84354                  26000
# 749212                  176682                  20000
# 418195                   19609                  52000
# 331862                  123755                  26000
#
#                                NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 758046  Ministério da Ciência, Tecnologia, Inovações          20301
# 656884                         Ministério da Educação         26246
# 749212                       Presidência da República         20116
# 418195                           Ministério da Defesa         52221
# 331862                         Ministério da Educação         26409
#
#                                  NOMBRE_ÓRGANO CÓDIGO_UNIDAD_GESTORA  \
# 758046    Comissão Nacional de Energia Nuclear                113209
# 656884  Universidade Federal de Santa Catarina                153163
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Industrial'])
# Out:
# La tabla tiene 18857 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64           18857
# CÓDIGO_ÓRGANO_SUPERIOR                    object           18857
# NOMBRE_ÓRGANO_SUPERIOR                    object           18857
# CÓDIGO_ÓRGANO                             object           18857
# NOMBRE_ÓRGANO                             object           18857
# CÓDIGO_UNIDAD_GESTORA                     object           18857
# NOMBRE_UNIDAD_GESTORA                     object           18857
# CATEGORÍA_ECONÓMICA                       object           18857
# ORIGEN_INGRESO                            object           18857
# TIPO_INGRESO                              object           18857
# DETALLE                                   object           18857
# VALOR_PREVISTO_ACTUALIZADO               float64           18857
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Industrial'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Receita Industrial                        18695
# Receitas da indústria de transformação      162
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Industrial'].DETALLE.value_counts()
# Out:
# DETALLE
# RECEITA INDUSTRIAL-PRINCIPAL                     15069
# RECEITA INDUSTRIAL-PRINCIPAL-INTRA                1867
# RECEITA INDUSTRIAL-MULTAS E JUROS                 1747
# RECEITA DA INDUSTRIA EDITORIAL E GRAFICA            56
# RECEITA DA INDUSTRIA DE PRODUTOS ALIMENTARES        37
# RECEITA DA INDUSTRIA MECANICA                       13
# OUTRAS RECEITAS DA INDUSTRIA DE TRANSFORMACAO       13
# RECEITA INDUSTRIAL-DIVIDA ATIVA                     11
# RECEITA DA INDÚST. DE PRODUTOS FARMACÊUTICOS         9
# RECEITA DA INDUSTRIA QUIMICA                         9
# RECEITA DA INDUSTRIA DE BEBIDAS E DESTILADOS         8
# RECEITA DA INDUSTRIA ELETRONICA                      5
# RECEITA DA INDUST. DE PRODUTOS FARMACEUTICOS         4
# RECEITA DA INDUSTRIA DE PROD.FARMOQUIMICOS           3
# RECEITA DA INDUSTRIA DE PROD. FARMOQUIMICOS          3
# RECEITA DA INDÚST. DE PRODUTOS VETERINÁRIOS          2
# RECEITA INDUSTRIAL-MULTAS E JUROS-INTRA              1
# ...

# %% [markdown]
# Sustituyo RECEITA DA INDÚST. DE PRODUTOS FARMACÊUTICOS  por RECEITA DA INDUST. DE PRODUTOS FARMACEUTICOS
# Sustituyo RECEITA DA INDUSTRIA DE PROD.FARMOQUIMICOS  por RECEITA DA INDUSTRIA DE PROD. FARMOQUIMICOS

# %%
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('RECEITA DA INDÚST. DE PRODUTOS FARMACÊUTICOS', 'RECEITA DA INDUST. DE PRODUTOS FARMACEUTICOS')
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('RECEITA DA INDUSTRIA DE PROD.FARMOQUIMICOS', 'RECEITA DA INDUSTRIA DE PROD. FARMOQUIMICOS')

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Industrial'].DETALLE.value_counts()
# Out:
# DETALLE
# RECEITA INDUSTRIAL-PRINCIPAL                     15069
# RECEITA INDUSTRIAL-PRINCIPAL-INTRA                1867
# RECEITA INDUSTRIAL-MULTAS E JUROS                 1747
# RECEITA DA INDUSTRIA EDITORIAL E GRAFICA            56
# RECEITA DA INDUSTRIA DE PRODUTOS ALIMENTARES        37
# OUTRAS RECEITAS DA INDUSTRIA DE TRANSFORMACAO       13
# RECEITA DA INDUST. DE PRODUTOS FARMACEUTICOS        13
# RECEITA DA INDUSTRIA MECANICA                       13
# RECEITA INDUSTRIAL-DIVIDA ATIVA                     11
# RECEITA DA INDUSTRIA QUIMICA                         9
# RECEITA DA INDUSTRIA DE BEBIDAS E DESTILADOS         8
# RECEITA DA INDUSTRIA DE PROD. FARMOQUIMICOS          6
# RECEITA DA INDUSTRIA ELETRONICA                      5
# RECEITA DA INDÚST. DE PRODUTOS VETERINÁRIOS          2
# RECEITA INDUSTRIAL-MULTAS E JUROS-INTRA              1
# Name: count, dtype: int64

# %% [markdown]
# Analizo Contribuições

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Contribuições'].sample(5)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 21824                     8250                  22000
# 636134                   63604                  25000
# 917612                   25906                  25000
# 367306                  159199                  41000
# 789146                   39788                  25000
#
#                                NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 21824   Ministério da Agricultura, Pecuária e Abastec         22000
# 636134                         Ministério da Economia         25000
# 917612                         Ministério da Economia         25000
# 367306                    Ministério das Comunicações         41903
# 789146                         Ministério da Economia         25000
#
#                                             NOMBRE_ÓRGANO  \
# 21824   Ministério da Agricultura, Pecuária e Abasteci...
# 636134  Ministério da Economia - Unidades com vínculo ...
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Contribuições'])
# Out:
# La tabla tiene 66781 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64           66781
# CÓDIGO_ÓRGANO_SUPERIOR                    object           66781
# NOMBRE_ÓRGANO_SUPERIOR                    object           66781
# CÓDIGO_ÓRGANO                             object           66781
# NOMBRE_ÓRGANO                             object           66781
# CÓDIGO_UNIDAD_GESTORA                     object           66781
# NOMBRE_UNIDAD_GESTORA                     object           66781
# CATEGORÍA_ECONÓMICA                       object           66781
# ORIGEN_INGRESO                            object           66781
# TIPO_INGRESO                              object           66781
# DETALLE                                   object           66781
# VALOR_PREVISTO_ACTUALIZADO               float64           66781
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Contribuições'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Contribuições econômicas                         35123
# Contribuições sociais                            31576
# Contribuições para Entidades Privadas de Serv       82
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Contribuições'].DETALLE.value_counts()
# Out:
# DETALLE
# COTA-PARTE DO AFRMM-PRINCIPAL                    6955
# CONTRIB.P/FOMENTO RADIODIFUSAO PUBLICA-PRINC.    4233
# CONTR.S/REC.BRT EMP.PREST.SERV.TELECOM-PRINC.    3902
# CONDECINE-PRINCIPAL                              2590
# CONTR.S/REC.OP.BRT DECOR.SERV.TELECOM-PRINC.     2395
#                                                  ...
# COFINS SOBRE O FATURAMENTO-SIMPLES-DÍV.ATIVA        1
# COFINS S/FATURAMENTO-SIMPLES-MULTAS DÍV.ATIVA       1
# OUTRAS CONTRIBUICOES ECONOMICAS                     1
# ADICIONAL A CONTRIBUICAO PARA O SENAC               1
# CERTIFICADOS DA DIVIDA PUBLICA - CDP                1
# Name: count, Length: 512, dtype: int64

# %% [markdown]
# La categoría Contribuciones tiene muchas opciones en el detalle, me es complicado analizar si existen duplicados

# %% [markdown]
# Analizo Impostos, Taxas e Contribuições de Melhoria

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Impostos, Taxas e Contribuições de Melhoria'].sample(5)
# Out:
#          INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 546694                   148108                  36000
# 846875                    97517                  26000
# 1005461                  113755                  36000
# 994878                   103172                  39000
# 416908                    18322                  52000
#
#                NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 546694            Ministério da Saúde         36212
# 846875         Ministério da Educação         26290
# 1005461           Ministério da Saúde         36213
# 994878   Ministério da Infraestrutura         62201
# 416908           Ministério da Defesa         52904
#
#                                              NOMBRE_ÓRGANO  \
# 546694            Agência Nacional de Vigilância Sanitária
# 846875   Instituto Nacional de Estudos e Pesquisas Educ...
# 1005461              Agência Nacional de Saúde Suplementar
# 994878                   Agência Nacional de Aviação Civil
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Impostos, Taxas e Contribuições de Melhoria'])
# Out:
# La tabla tiene 78340 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64           78340
# CÓDIGO_ÓRGANO_SUPERIOR                    object           78340
# NOMBRE_ÓRGANO_SUPERIOR                    object           78340
# CÓDIGO_ÓRGANO                             object           78340
# NOMBRE_ÓRGANO                             object           78340
# CÓDIGO_UNIDAD_GESTORA                     object           78340
# NOMBRE_UNIDAD_GESTORA                     object           78340
# CATEGORÍA_ECONÓMICA                       object           78340
# ORIGEN_INGRESO                            object           78340
# TIPO_INGRESO                              object           78340
# DETALLE                                   object           78340
# VALOR_PREVISTO_ACTUALIZADO               float64           78340
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Impostos, Taxas e Contribuições de Melhoria'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Taxas       62336
# Impostos    16004
# Name: count, dtype: int64

# %% [markdown]
# Tiene muchas opciones en DETALLE, me es complicado analizar si existen categorías duplicadas

# %% [markdown]
# Analizo Receita Patrimonial

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Patrimonial'].sample(5)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 324378                  116271                  26000
# 939076                   47370                  25000
# 980499                   88793                  26000
# 495967                   97381                  26000
# 375851                  167744                  32000
#
#                NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 324378         Ministério da Educação         26435
# 939076         Ministério da Economia         25000
# 980499         Ministério da Educação         26412
# 495967         Ministério da Educação         26258
# 375851  Ministério de Minas e Energia         32263
#
#                                             NOMBRE_ÓRGANO  \
# 324378           Instituto Federal do Rio Grande do Norte
# 939076  Ministério da Economia - Unidades com vínculo ...
# 980499           Instituto Federal do Sul de Minas Gerais
# 495967         Universidade Tecnológica Federal do Paraná
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Patrimonial'])
# Out:
# La tabla tiene 163171 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64          163171
# CÓDIGO_ÓRGANO_SUPERIOR                    object          163171
# NOMBRE_ÓRGANO_SUPERIOR                    object          163171
# CÓDIGO_ÓRGANO                             object          163171
# NOMBRE_ÓRGANO                             object          163171
# CÓDIGO_UNIDAD_GESTORA                     object          163171
# NOMBRE_UNIDAD_GESTORA                     object          163171
# CATEGORÍA_ECONÓMICA                       object          163171
# ORIGEN_INGRESO                            object          163171
# TIPO_INGRESO                              object          163171
# DETALLE                                   object          163171
# VALOR_PREVISTO_ACTUALIZADO               float64          163171
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Patrimonial'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Exploração do patrimônio imobiliário do Estad    88862
# Valores Mobiliários                              33037
# Exploração de recursos naturais                  21667
# Delegação de Serviços Públicos Mediante Conce    15843
# Demais receitas patrimoniais                      1744
# Cessão de direitos                                1504
# Receita de concessões e permissões                 403
# Exploração do patrimônio intangível                 93
# Receitas de valores mobiliários                     18
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Patrimonial'].CATEGORÍA_ECONÓMICA.value_counts()
# Out:
# CATEGORÍA_ECONÓMICA
# Receitas Correntes                          161974
# Receitas Correntes - intra-orçamentárias      1197
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita Patrimonial'].DETALLE.value_counts()
# Out:
# DETALLE
# ALUGUEIS E ARRENDAMENTOS-PRINCIPAL               71040
# REMUNERACAO DE DEPOSITOS BANCARIOS-PRINCIPAL     30435
# ALUGUEIS E ARRENDAMENTOS-MULTAS E JUROS          10308
# COMPENS.FINANC.EXPL.RECURSOS MINERAIS-PRINC.      5414
# CONC/PERM/AUT/CESSAO DIR.USO IMOV.PUB-PRINC.      4840
#                                                  ...
# DELEG.P/PREST.SERV.TRANSP.RODOVIARIO-MUL.JUR.        1
# BÔNUS ASS.CONTR.PARTIL.PROD-GEST.CONTR-PRINC.        1
# DELEG.P/EXPL.INFRA.TRANSP.FERROVIARIO-PRINC.         1
# UTIL.REC.HID-DEM.EMPRESAS-PRORROG.OUT-MUL.JUR        1
# OUTORGA DIR.USO DE RECURSOS HIDRICOS-DIV.AT.         1
# Name: count, Length: 224, dtype: int64

# %% [markdown]
# Tiene muchas opciones en el DETALLE, me es complicado analizar si tiene duplicados

# %% [markdown]
# Analizo Receita de Serviços

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita de Serviços'].sample(5)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  NOMBRE_ÓRGANO_SUPERIOR  \
# 570461                  171875                  54000   Ministério do Turismo
# 499457                  100871                  26000  Ministério da Educação
# 823625                   74267                  26000  Ministério da Educação
# 93207                    79633                  26000  Ministério da Educação
# 498464                   99878                  26000  Ministério da Educação
#
#        CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 570461         34902                          Fundo Nacional de Cultura
# 499457         26257  Centro Federal de Educação Tecnológica de Mina...
# 823625         26273                 Universidade Federal do Rio Grande
# 93207          26413             Instituto Federal do Triângulo Mineiro
# 498464         26262                  Universidade Federal de São Paulo
#
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita de Serviços'])
# Out:
# La tabla tiene 322319 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64          322319
# CÓDIGO_ÓRGANO_SUPERIOR                    object          322319
# NOMBRE_ÓRGANO_SUPERIOR                    object          322319
# CÓDIGO_ÓRGANO                             object          322319
# NOMBRE_ÓRGANO                             object          322319
# CÓDIGO_UNIDAD_GESTORA                     object          322319
# NOMBRE_UNIDAD_GESTORA                     object          322319
# CATEGORÍA_ECONÓMICA                       object          322319
# ORIGEN_INGRESO                            object          322319
# TIPO_INGRESO                              object          322319
# DETALLE                                   object          322319
# VALOR_PREVISTO_ACTUALIZADO               float64          322319
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita de Serviços'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Serviços Administrativos e Comerciais Gerais     278157
# Serviços e Atividades Referentes à Saúde          14902
# Outros serviços                                    9655
# Serviços e Atividades Financeiras                  8902
# Serviços e Atividades Referentes à Navegação       7813
# Receita de Serviços                                2890
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Receita de Serviços'].DETALLE.value_counts()
# Out:
# DETALLE
# SERV.ADMINISTRAT.E COMERCIAIS GERAIS-PRINC.      159039
# INSCR.EM CONCURSOS E PROC.SELETIVOS-PRINCIPAL     74638
# SERVICOS DE INFORMACAO E TECNOLOGIA-PRINCIPAL     17785
# SERV.DE REGIST.,CERTIF.E FISCALIZ.-PRINCIPAL      13810
# OUTROS SERVICOS-PRINCIPAL                          9440
#                                                   ...
# SERV.DECORREN.PARCEIR.C/OUTRAS INST.PUB.PRIV.         1
# SERVICOS DE SOCORRO MARITIMO                          1
# SERV.ADMINISTRAT.E COMERCIAIS GERAIS-DIV.AT.          1
# SERVICOS DE TRANSPORTE-MULTAS E JUROS                 1
# SERV.ADMIN.E COMERCIAIS GERAIS-MUL.JUR-INTRA          1
# Name: count, Length: 132, dtype: int64

# %% [markdown]
# Analizo Outras Receitas Correntes

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Outras Receitas Correntes'].sample(5)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 348948                  140841                  39000
# 187364                  173790                  32000
# 945664                   53958                  25000
# 693912                  121382                  26000
# 233681                   25574                  52000
#
#                NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 348948   Ministério da Infraestrutura         39250
# 187364  Ministério de Minas e Energia         32205
# 945664         Ministério da Economia         25000
# 693912         Ministério da Educação         26282
# 233681           Ministério da Defesa         52131
#
#                                             NOMBRE_ÓRGANO  \
# 348948         Agência Nacional de Transportes Terrestres
# 187364  Agência Nacional do Petróleo, Gás Natural e Bi...
# 945664  Ministério da Economia - Unidades com vínculo ...
# 693912                     Universidade Federal de Viçosa
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Outras Receitas Correntes'])
# Out:
# La tabla tiene 322907 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64          322907
# CÓDIGO_ÓRGANO_SUPERIOR                    object          322907
# NOMBRE_ÓRGANO_SUPERIOR                    object          322907
# CÓDIGO_ÓRGANO                             object          322907
# NOMBRE_ÓRGANO                             object          322907
# CÓDIGO_UNIDAD_GESTORA                     object          322907
# NOMBRE_UNIDAD_GESTORA                     object          322907
# CATEGORÍA_ECONÓMICA                       object          322907
# ORIGEN_INGRESO                            object          322907
# TIPO_INGRESO                              object          322907
# DETALLE                                   object          322907
# VALOR_PREVISTO_ACTUALIZADO               float64          322907
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Outras Receitas Correntes'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Indenizações, restituições e ressarcimentos      143577
# Multas administrativas, contratuais e judicia    115276
# Demais receitas correntes                         55079
# Bens, Direitos e Valores Incorporados ao Patr      8245
# Indenizações e restituições                         724
# Receitas decorrentes de aportes periódicos pa         3
# Receitas decorrentes de compensações ao Regim         2
# Receita da dívida ativa                               1
# Name: count, dtype: int64

# %% [markdown]
# Las Receitas de capital deben tener solo las sisguientes categorías:
# 1. Operações de Crédito
# 2.	Alienação de Bens
# 3.	Amortização de Empréstimos
# 4.	Transferências de Capital
# 9.	Outras Receitas de Capital

# %%
df_total_anos[df_total_anos.CATEGORIA_ECONÓMICA_AGRUPADA == 'Receitas de Capital'].ORIGEN_INGRESO.value_counts()
# Out:
# ORIGEN_INGRESO
# Alienação de Bens              12418
# Amortizações de Empréstimos    11318
# Operações de Crédito            5044
# Outras Receitas de Capital      1060
# Transferências de Capital        371
# Name: count, dtype: int64

# %% [markdown]
# Todas tienen una categoría correcta

# %% [markdown]
# Analizo Alienação de Bens

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Alienação de Bens'].sample(5)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 558133                  159547                  53000
# 217794                    9687                  22000
# 586393                   13863                  52000
# 16824                     3250                  22000
# 403547                    4961                  22000
#
#                                NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 558133         Ministério do Desenvolvimento Regional         22203
# 217794  Ministério da Agricultura, Pecuária e Abastec         22201
# 586393                           Ministério da Defesa         52132
# 16824   Ministério da Agricultura, Pecuária e Abastec         22201
# 403547  Ministério da Agricultura, Pecuária e Abastec         22201
#
#                                             NOMBRE_ÓRGANO  \
# 558133  Companhia de Desenvolvimento dos Vales do São ...
# 217794  Instituto Nacional de Colonização e Reforma Ag...
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Alienação de Bens'])
# Out:
# La tabla tiene 12418 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64           12418
# CÓDIGO_ÓRGANO_SUPERIOR                    object           12418
# NOMBRE_ÓRGANO_SUPERIOR                    object           12418
# CÓDIGO_ÓRGANO                             object           12418
# NOMBRE_ÓRGANO                             object           12418
# CÓDIGO_UNIDAD_GESTORA                     object           12418
# NOMBRE_UNIDAD_GESTORA                     object           12418
# CATEGORÍA_ECONÓMICA                       object           12418
# ORIGEN_INGRESO                            object           12418
# TIPO_INGRESO                              object           12418
# DETALLE                                   object           12418
# VALOR_PREVISTO_ACTUALIZADO               float64           12418
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Alienação de Bens'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Alienação de bens imóveis        7877
# Alienação de bens móveis         4510
# Alienação de bens intangíveis      31
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Alienação de Bens'].DETALLE.value_counts()
# Out:
# DETALLE
# ALIENACAO DE BENS IMOVEIS-PRINCIPAL              3621
# ALIENACAO DE BENS MOVEIS E SEMOVENTES-PRINC.     3511
# ALIENAÇÃO DE BENS IMÓVEIS-PRINCIPAL              1861
# ALIENACAO DE BENS IMOVEIS-JUROS                   671
# ALIENACAO DE BENS IMOVEIS-MULTAS E JUROS          594
# ALIENACAO DE BENS IMOVEIS-MULTAS                  510
# ALIENAÇÃO DE BENS IMÓVEIS-JUROS                   415
# ALIENACAO DE ESTOQUES DA PGPM-PRINCIPAL           290
# ALIENAÇÃO DE BENS IMÓVEIS-MULTAS E JUROS          131
# ALIENACAO DE TITULOS MOBILIARIOS-PRINCIPAL        119
# ALIENACAO DE ESTOQUES DE CAFE-FUNCAFE-DIV.AT.     109
# ALIENACAO DE VEICULOS                             106
# ALIENACAO DE OUTROS BENS MOVEIS                    83
# ALIENACAO DE MOVEIS E UTENSILIOS                   82
# ALIENACAO DE EQUIPAMENTOS                          78
# ALIENACAO DE IMOVEIS URBANOS                       34
# ALIENACAO DE BENS MOVEIS E SEMOVENTES-MUL.JUR      31
# ...

# %% [markdown]
# Sustituyo ALIENAÇÃO  por ALIENACAO
# Sustituyo IMÓVEIS por IMOVEIS

# %%
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('ALIENAÇÃO', 'ALIENACAO')
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('IMÓVEIS', 'IMOVEIS')

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Alienação de Bens'].DETALLE.value_counts()
# Out:
# DETALLE
# ALIENACAO DE BENS IMOVEIS-PRINCIPAL              5482
# ALIENACAO DE BENS MOVEIS E SEMOVENTES-PRINC.     3511
# ALIENACAO DE BENS IMOVEIS-JUROS                  1086
# ALIENACAO DE BENS IMOVEIS-MULTAS E JUROS          725
# ALIENACAO DE BENS IMOVEIS-MULTAS                  510
# ALIENACAO DE ESTOQUES DA PGPM-PRINCIPAL           290
# ALIENACAO DE TITULOS MOBILIARIOS-PRINCIPAL        119
# ALIENACAO DE ESTOQUES DE CAFE-FUNCAFE-DIV.AT.     109
# ALIENACAO DE VEICULOS                             106
# ALIENACAO DE OUTROS BENS MOVEIS                    83
# ALIENACAO DE MOVEIS E UTENSILIOS                   82
# ALIENACAO DE EQUIPAMENTOS                          78
# ALIENACAO DE IMOVEIS URBANOS                       34
# ALIENACAO DE BENS MOVEIS E SEMOVENTES-MUL.JUR      31
# ALIEN.ESTOQ.PROG.AQUIS.ALIMENTOS-PAA-PRINC.        29
# ALIENACAO DE ANIMAIS REPRODUTORES E MATRIZES       25
# ALIENACAO DE BENS INTANGIVEIS-PRINCIPAL            25
# ...

# %% [markdown]
# Analizo Amortizações de Empréstimos

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Amortizações de Empréstimos'].sample(5)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  \
# 921725                   30019                  25000
# 190779                  177205                  53000
# 13231                     4180                  53000
# 798590                   49232                  25000
# 572881                     351                  22000
#
#                                NOMBRE_ÓRGANO_SUPERIOR CÓDIGO_ÓRGANO  \
# 921725                         Ministério da Economia         25000
# 190779         Ministério do Desenvolvimento Regional         74919
# 13231          Ministério do Desenvolvimento Regional         74919
# 798590                         Ministério da Economia         25000
# 572881  Ministério da Agricultura, Pecuária e Abastec         22201
#
#                                             NOMBRE_ÓRGANO  \
# 921725  Ministério da Economia - Unidades com vínculo ...
# 190779           Fundo de Desenvolvimento do Centro-Oeste
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Amortizações de Empréstimos'])
# Out:
# La tabla tiene 11318 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64           11318
# CÓDIGO_ÓRGANO_SUPERIOR                    object           11318
# NOMBRE_ÓRGANO_SUPERIOR                    object           11318
# CÓDIGO_ÓRGANO                             object           11318
# NOMBRE_ÓRGANO                             object           11318
# CÓDIGO_UNIDAD_GESTORA                     object           11318
# NOMBRE_UNIDAD_GESTORA                     object           11318
# CATEGORÍA_ECONÓMICA                       object           11318
# ORIGEN_INGRESO                            object           11318
# TIPO_INGRESO                              object           11318
# DETALLE                                   object           11318
# VALOR_PREVISTO_ACTUALIZADO               float64           11318
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Amortizações de Empréstimos'].DETALLE.value_counts()
# Out:
# DETALLE
# AMORTIZACAO DE EMPRESTIMOS CONTRATUAIS-PRINC.    5468
# AMORTIZACAO DE FINANCIAMENTOS-PRINCIPAL          1495
# AMORT.EMPREST.-PROG.OP.OFICIAIS CRED.-PRINC.     1471
# AMORTIZACAO DE EMPRESTIMOS-EST/MUN-PRINCIPAL     1350
# AMORTIZACAO EMPRESTIMOS CONTRATUAIS-MUL.JUR.      681
# AMORTIZACAO DE FINANCIAMENTO DO FIES-PRINC.       326
# AMORTIZ.PROV.EXEC.DE GARANTIA-OP.CRED.-PRINC.     257
# AMORTIZACAO DE FINANCIAMENTOS-MULTAS E JUROS       81
# AMORT.EMPREST.-PROG.OP.OFICIAIS CRED.-MUL.JUR      70
# AMORT.EMPR.-REFIN.DIV.MED.E LONGO PRAZO-PRINC      28
# AMORTIZACOES DE PROJETOS                           23
# AMORTIZ.FINANC.PROV.FUNDO GARANTIDOR-PRINC.        19
# AMORTIZACOES DE EMPRESTIMOS DIVERSOS               14
# AMORTIZACOES DE CONTRATOS                          11
# AMORTIZACOES DE BENS                                9
# AMORT. REFINANC. - DIVIDAS E OP MEDIO E DE LP       3
# PROGRAMAS DAS OPERACOES OFICIAIS DE CREDITO         3
# ...

# %% [markdown]
# No veo ningún duplicado

# %% [markdown]
# Analizo Operações de Crédito

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Operações de Crédito'].sample(5)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  NOMBRE_ÓRGANO_SUPERIOR  \
# 267571                   59464                  25000  Ministério da Economia
# 62970                    49396                  25000  Ministério da Economia
# 463269                   64683                  25000  Ministério da Economia
# 228989                   20882                  52000    Ministério da Defesa
# 37298                    23724                  52000    Ministério da Defesa
#
#        CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 267571         25000  Ministério da Economia - Unidades com vínculo ...
# 62970          25000  Ministério da Economia - Unidades com vínculo ...
# 463269         25000  Ministério da Economia - Unidades com vínculo ...
# 228989         52131                                 Comando da Marinha
# 37298          52111                             Comando da Aeronáutica
#
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Operações de Crédito'])
# Out:
# La tabla tiene 5044 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64            5044
# CÓDIGO_ÓRGANO_SUPERIOR                    object            5044
# NOMBRE_ÓRGANO_SUPERIOR                    object            5044
# CÓDIGO_ÓRGANO                             object            5044
# NOMBRE_ÓRGANO                             object            5044
# CÓDIGO_UNIDAD_GESTORA                     object            5044
# NOMBRE_UNIDAD_GESTORA                     object            5044
# CATEGORÍA_ECONÓMICA                       object            5044
# ORIGEN_INGRESO                            object            5044
# TIPO_INGRESO                              object            5044
# DETALLE                                   object            5044
# VALOR_PREVISTO_ACTUALIZADO               float64            5044
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Operações de Crédito'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Operações de crédito - mercado interno    2759
# Operações de crédito - mercado externo    2285
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Operações de Crédito'].DETALLE.value_counts()
# Out:
# DETALLE
# OP.DE CREDITO CONTRATUAIS-MERC.EXTERNO-PRINC.    2202
# TIT.RESP.TN-REFIN.DIV.PUB.FED.MERC.INT.-PRINC    1479
# TITULOS DE RESPONS.TES.NAC.-MERC.INT.-PRINC.      847
# OUTRAS OPER.DE CREDITO-MERCADO INTERNO-PRINC.     219
# TITULOS DA DIVIDA AGRARIA-TDA-PRINCIPAL            60
# TÍT.RESP.TN-REFIN.DÍV.PÚB.FED.INT-PRINC-INTRA      53
# EMPRÉSTIMOS COMPULSÓRIOS                           49
# OPERACOES DE CREDITOS EXTERNAS - CONTRATUAIS       42
# TITULOS DE RESPONS.TES.NAC.-MERC.EXT.-PRINC.       16
# TIT.RESP.TN-REFIN.DIV.PUB.FED.INT-PRINC-INTRA      15
# TIT.RESP.TN-REFIN.DIV.PUB.FED.MERC.EXT.-PRINC      15
# EMPRESTIMOS COMPULSORIOS                           13
# TITULOS DA DIVIDA AGRARIA - TDA                     6
# TIT.RESP.T.N.-REFINANC.DIVIDA PUBLICA FEDERAL       6
# OPERACOES DE CREDITO INTERNAS - CONTRATUAIS         5
# OP.CREDITO CONTRATUAIS-MERCADO INTERNO-PRINC.       4
# OUTRAS OPERACOES DE CREDITO EXTERNAS                3
# ...

# %% [markdown]
# Sustituyo TÍT.RESP.TN-REFIN.DÍV.PÚB.FED.INT-PRINC-INTRA  por TIT.RESP.TN-REFIN.DIV.PUB.FED.INT-PRINC-INTRA
#
#
# Sustituyo EMPRÉSTIMOS COMPULSÓRIOS por EMPRESTIMOS COMPULSORIOS

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Operações de Crédito'].DETALLE.value_counts()
# Out:
# DETALLE
# OP.DE CREDITO CONTRATUAIS-MERC.EXTERNO-PRINC.    2202
# TIT.RESP.TN-REFIN.DIV.PUB.FED.MERC.INT.-PRINC    1479
# TITULOS DE RESPONS.TES.NAC.-MERC.INT.-PRINC.      847
# OUTRAS OPER.DE CREDITO-MERCADO INTERNO-PRINC.     219
# TITULOS DA DIVIDA AGRARIA-TDA-PRINCIPAL            60
# TÍT.RESP.TN-REFIN.DÍV.PÚB.FED.INT-PRINC-INTRA      53
# EMPRÉSTIMOS COMPULSÓRIOS                           49
# OPERACOES DE CREDITOS EXTERNAS - CONTRATUAIS       42
# TITULOS DE RESPONS.TES.NAC.-MERC.EXT.-PRINC.       16
# TIT.RESP.TN-REFIN.DIV.PUB.FED.INT-PRINC-INTRA      15
# TIT.RESP.TN-REFIN.DIV.PUB.FED.MERC.EXT.-PRINC      15
# EMPRESTIMOS COMPULSORIOS                           13
# TITULOS DA DIVIDA AGRARIA - TDA                     6
# TIT.RESP.T.N.-REFINANC.DIVIDA PUBLICA FEDERAL       6
# OPERACOES DE CREDITO INTERNAS - CONTRATUAIS         5
# OP.CREDITO CONTRATUAIS-MERCADO INTERNO-PRINC.       4
# OUTRAS OPERACOES DE CREDITO EXTERNAS                3
# ...

# %%
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('TÍT.RESP.TN-REFIN.DÍV.PÚB.FED.INT-PRINC-INTRA', 'TIT.RESP.TN-REFIN.DIV.PUB.FED.INT-PRINC-INTRA')    
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('EMPRÉSTIMOS COMPULSÓRIOS', 'EMPRESTIMOS COMPULSORIOS')

# %% [markdown]
# Analizo Outras Receitas de Capital

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Outras Receitas de Capital'].sample(5)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  NOMBRE_ÓRGANO_SUPERIOR  \
# 446321                   47735                  25000  Ministério da Economia
# 784906                   35548                  25000  Ministério da Economia
# 615434                   42904                  25000  Ministério da Economia
# 54512                    40938                  25000  Ministério da Economia
# 446362                   47776                  25000  Ministério da Economia
#
#        CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 446321         25000  Ministério da Economia - Unidades com vínculo ...
# 784906         25000  Ministério da Economia - Unidades com vínculo ...
# 615434         25000  Ministério da Economia - Unidades com vínculo ...
# 54512          25000  Ministério da Economia - Unidades com vínculo ...
# 446362         25000  Ministério da Economia - Unidades com vínculo ...
#
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Outras Receitas de Capital'])
# Out:
# La tabla tiene 1060 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64            1060
# CÓDIGO_ÓRGANO_SUPERIOR                    object            1060
# NOMBRE_ÓRGANO_SUPERIOR                    object            1060
# CÓDIGO_ÓRGANO                             object            1060
# NOMBRE_ÓRGANO                             object            1060
# CÓDIGO_UNIDAD_GESTORA                     object            1060
# NOMBRE_UNIDAD_GESTORA                     object            1060
# CATEGORÍA_ECONÓMICA                       object            1060
# ORIGEN_INGRESO                            object            1060
# TIPO_INGRESO                              object            1060
# DETALLE                                   object            1060
# VALOR_PREVISTO_ACTUALIZADO               float64            1060
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Outras Receitas de Capital'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Remuneração das Disponibilidades do Tesouro      1002
# Resultado do Banco Central do Brasil               22
# Resgate de Títulos do Tesouro                      13
# Receita títulos do tesouro nacional resgatado       6
# Receita dívida ativa proveniente de amortizaç       5
# Receita dívida ativa alienação de estoques de       3
# Outras receitas                                     3
# Remuneração das Disponibilidades do Tesouro N       3
# Demais receitas de capital                          2
# Integralização do capital social                    1
# Name: count, dtype: int64

# %% [markdown]
# Agrupo Outras receitas con Demais receitas de capital

# %%
df_total_anos['TIPO_INGRESO'] = df_total_anos['TIPO_INGRESO'].str.replace('Outras receitas', 'Demais receitas de capital')

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Outras Receitas de Capital'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Remuneração das Disponibilidades do Tesouro      1002
# Resultado do Banco Central do Brasil               22
# Resgate de Títulos do Tesouro                      13
# Receita títulos do tesouro nacional resgatado       6
# Demais receitas de capital                          5
# Receita dívida ativa proveniente de amortizaç       5
# Receita dívida ativa alienação de estoques de       3
# Remuneração das Disponibilidades do Tesouro N       3
# Integralização do capital social                    1
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Outras Receitas de Capital'].DETALLE.value_counts()
# Out:
# DETALLE
# REMUNER.DISPONIBILIDADES TES.NACIONAL-PRINC.     997
# RESULTADO DO BACEN-DEMAIS OPERACOES-PRINCIPAL     13
# RESGATE DE TITULOS DO TESOURO-PRINCIPAL            9
# Receita títulos do tesouro nacional resgatado      5
# REMUNER.DISPONIBILIDADES TES.NACIONAL-MUL.JUR      5
# RESGATE DE TITULOS DO TESOURO-MULTAS E JUROS       4
# RES.BCO CENTRAL-OPER.C/RESERV.E DER.CAMBIAIS       3
# Receita dívida ativa proveniente de amortizaç      3
# RES.BACEN-OP.C/RESERV.E DERIV.CAMBIAIS-PRINC.      3
# Outras receitas                                    3
# RESULTADO DO BANCO CENTRAL-DEMAIS OPERAÇÕES        2
# Receita dívida ativa alienação de estoques de      2
# REC.DIV.ATIVA PROV.DE AMORTIZ.EMPREST.FINANC.      2
# Remuneração das Disponibilidades do Tesouro N      2
# DEMAIS RECEITAS DE CAPITAL-PRINCIPAL               2
# INTEGRALIZACAO COM RECURSOS DE OUTRAS FONTES       1
# REMUNERACAO DAS DISPONIBILIDADES TES.NACIONAL      1
# RESULTADO DO BANCO CENTRAL-DEMAIS OPERACOES        1
# ...

# %% [markdown]
# Sustituyo Receita títulos do tesouro nacional resgatado por RECEITA TITULOS DO TESOURO NACIONAL RESGATADO
#
# Sustituyo Remuneração das Disponibilidades do Tesouro N por REMUNERACAO DAS DISPONIBILIDADES TES.NACIONAL
#
# Sustituyo Outras receitas por DEMAIS RECEITAS DE CAPITAL-PRINCIPAL
#
# Sustituyo Receita dívida ativa proveniente de amortizaç por REC.DIV.ATIVA PROV.DE AMORTIZ.EMPREST.FINANC
#
# Sustitutyo Receita dívida ativa alienação de estoques de  por RECEITA DIV ATIVA ALIENACAO ESTOQUES DE CAFE

# %%
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('Receita títulos do tesouro nacional resgatado', 'RECEITA TITULOS DO TESOURO NACIONAL RESGATADO')
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('Remuneração das Disponibilidades do Tesouro N', 'REMUNERACAO DAS DISPONIBILIDADES TES.NACIONAL')
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('Outras receitas', 'DEMAIS RECEITAS DE CAPITAL-PRINCIPAL')
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('Receita dívida ativa proveniente de amortizaç', 'REC.DIV.ATIVA PROV.DE AMORTIZ.EMPREST.FINANC')
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('Receita dívida ativa alienação de estoques de', 'RECEITA DIV ATIVA ALIENACAO ESTOQUES DE CAFE')

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Outras Receitas de Capital'].DETALLE.value_counts()
# Out:
# DETALLE
# REMUNER.DISPONIBILIDADES TES.NACIONAL-PRINC.     997
# RESULTADO DO BACEN-DEMAIS OPERACOES-PRINCIPAL     13
# RESGATE DE TITULOS DO TESOURO-PRINCIPAL            9
# RECEITA TITULOS DO TESOURO NACIONAL RESGATADO      6
# REMUNER.DISPONIBILIDADES TES.NACIONAL-MUL.JUR      5
# DEMAIS RECEITAS DE CAPITAL-PRINCIPAL               5
# RESGATE DE TITULOS DO TESOURO-MULTAS E JUROS       4
# RECEITA DIV ATIVA ALIENACAO ESTOQUES DE CAFE       3
# REC.DIV.ATIVA PROV.DE AMORTIZ.EMPREST.FINANC       3
# RES.BACEN-OP.C/RESERV.E DERIV.CAMBIAIS-PRINC.      3
# RES.BCO CENTRAL-OPER.C/RESERV.E DER.CAMBIAIS       3
# REMUNERACAO DAS DISPONIBILIDADES TES.NACIONAL      3
# REC.DIV.ATIVA PROV.DE AMORTIZ.EMPREST.FINANC.      2
# RESULTADO DO BANCO CENTRAL-DEMAIS OPERAÇÕES        2
# INTEGRALIZACAO COM RECURSOS DE OUTRAS FONTES       1
# RESULTADO DO BANCO CENTRAL-DEMAIS OPERACOES        1
# Name: count, dtype: int64

# %% [markdown]
# Analizo Transferências de Capital

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'].sample(5)
# Out:
#         INDICE_DF_AÑO_ORIGINAL CÓDIGO_ÓRGANO_SUPERIOR  NOMBRE_ÓRGANO_SUPERIOR  \
# 414410                   15824                  52000    Ministério da Defesa
# 249812                   41705                  25000  Ministério da Economia
# 249848                   41741                  25000  Ministério da Economia
# 249742                   41635                  25000  Ministério da Economia
# 128321                  114747                  26000  Ministério da Educação
#
#        CÓDIGO_ÓRGANO                                      NOMBRE_ÓRGANO  \
# 414410         52000  Ministério da Defesa - Unidades com vínculo di...
# 249812         25201  Banco Central do Brasil - Orçamento Fiscal e S...
# 249848         25201  Banco Central do Brasil - Orçamento Fiscal e S...
# 249742         25201  Banco Central do Brasil - Orçamento Fiscal e S...
# 128321         26274        Fundação Universidade Federal de Uberlândia
#
# ...

# %%
se.reporte(df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'])
# Out:
# La tabla tiene 371 filas y 24 columnas
# La tabla tiene 0 filas duplicadas
#                                   tipo_variables  contador_total  \
# INDICE_DF_AÑO_ORIGINAL                     int64             371
# CÓDIGO_ÓRGANO_SUPERIOR                    object             371
# NOMBRE_ÓRGANO_SUPERIOR                    object             371
# CÓDIGO_ÓRGANO                             object             371
# NOMBRE_ÓRGANO                             object             371
# CÓDIGO_UNIDAD_GESTORA                     object             371
# NOMBRE_UNIDAD_GESTORA                     object             371
# CATEGORÍA_ECONÓMICA                       object             371
# ORIGEN_INGRESO                            object             371
# TIPO_INGRESO                              object             371
# DETALLE                                   object             371
# VALOR_PREVISTO_ACTUALIZADO               float64             371
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências de Instituições Privadas          123
# Transferências dos Municípios e de suas Entid     90
# Transferências de Pessoas Físicas                 41
# Transferências de Capital                         39
# Transferências dos Estados e do Distrito Fede     38
# Transferências do Exterior                        21
# Transferências da União e de suas Entidades       14
# Transferências de Outras Instituições Pública      5
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'].DETALLE.value_counts()
# Out:
# DETALLE
# TRANSF.DOS MUNICIPIOS E SUAS ENTIDADES-PRINC.    103
# TRANSFERENCIAS DE INSTITUICOES PRIVADAS-PRINC     95
# TRANSF.DOS ESTADOS,DF E SUAS ENTIDADES-PRINC.     35
# TRANSFERÊNCIAS DE INSTITUIÇÕES PRIVADAS-PRINC     31
# TRANSFERENCIAS DO EXTERIOR-PRINCIPAL              30
# TRANSFER.DA UNIAO E DE SUAS ENTIDADES-PRINC.      16
# TRANSF.DE CONV.DOS ESTADOS,DF E S/ENTIDADES       13
# TRANSF.DE CONVENIOS DE INSTITUICOES PRIVADAS      10
# TRANSF.DE CONVENIOS DA UNIAO DE S/ENTIDADES        9
# TRANSF.DE CONV.DOS MUNICIPIOS E S/ENTIDADES        8
# TRANSFERENCIAS A CONSORCIOS PUBLICOS               6
# TRANSFERENCIAS DE INSTITUICOES PRIVADAS            3
# Transferências do Exterior                         3
# TRANSF.DE OUTRAS INSTITUICOES PUBLICAS-PRINC.      3
# TRANSF.DE OUTRAS INSTITUIÇÕES PÚBLICAS-PRINC.      3
# TRANSFERENCIAS DO EXTERIOR                         1
# TRANSFERENCIA DE OUTRAS INSTITUICOES PUBLICAS      1
# TRANSFERENCIAS DE PESSOAS FISICAS-PRINCIPAL        1
# ...

# %% [markdown]
# Sustituyo INSTITUIÇÕES   por INSTITUICOES
# Sustituyo PÚBLICAS por PUBLICAS
# Sustituyo Transferências do Exterior   por TRANSFERENCIAS DO EXTERIOR
# Sustituyo TRANSFERÊNCIAS  por TRANSFERENCIAS

# %%
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('INSTITUIÇÕES', 'INSTITUICOES')
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('PÚBLICAS', 'PUBLICAS')
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('Transferências do Exterior', 'TRANSFERENCIAS DO EXTERIOR')
df_total_anos['DETALLE'] = df_total_anos['DETALLE'].str.replace('TRANSFERÊNCIAS', 'TRANSFERENCIAS')

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'].DETALLE.value_counts()
# Out:
# DETALLE
# TRANSFERENCIAS DE INSTITUICOES PRIVADAS-PRINC    126
# TRANSF.DOS MUNICIPIOS E SUAS ENTIDADES-PRINC.    103
# TRANSF.DOS ESTADOS,DF E SUAS ENTIDADES-PRINC.     35
# TRANSFERENCIAS DO EXTERIOR-PRINCIPAL              30
# TRANSFER.DA UNIAO E DE SUAS ENTIDADES-PRINC.      16
# TRANSF.DE CONV.DOS ESTADOS,DF E S/ENTIDADES       13
# TRANSF.DE CONVENIOS DE INSTITUICOES PRIVADAS      10
# TRANSF.DE CONVENIOS DA UNIAO DE S/ENTIDADES        9
# TRANSF.DE CONV.DOS MUNICIPIOS E S/ENTIDADES        8
# TRANSF.DE OUTRAS INSTITUICOES PUBLICAS-PRINC.      6
# TRANSFERENCIAS A CONSORCIOS PUBLICOS               6
# TRANSFERENCIAS DO EXTERIOR                         4
# TRANSFERENCIAS DE INSTITUICOES PRIVADAS            3
# TRANSFERENCIA DE OUTRAS INSTITUICOES PUBLICAS      1
# TRANSFERENCIAS DE PESSOAS FISICAS-PRINCIPAL        1
# Name: count, dtype: int64

# %% [markdown]
# Analizo el detalle del tipo de ingreso de transferencias de capital para ver si puedo categorizar esas transferencias correctamente:

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.TIPO_INGRESO== 'Transferências de Capital'].DETALLE.value_counts()
# Out:
# DETALLE
# TRANSF.DOS MUNICIPIOS E SUAS ENTIDADES-PRINC.    14
# TRANSFERENCIAS DO EXTERIOR-PRINCIPAL             13
# TRANSFERENCIAS DE INSTITUICOES PRIVADAS-PRINC     6
# TRANSF.DOS ESTADOS,DF E SUAS ENTIDADES-PRINC.     3
# TRANSFER.DA UNIAO E DE SUAS ENTIDADES-PRINC.      2
# TRANSF.DE OUTRAS INSTITUICOES PUBLICAS-PRINC.     1
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSF.DOS MUNICIPIOS E SUAS ENTIDADES-PRINC.'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências dos Municípios e de suas Entid    89
# Transferências de Capital                        14
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSF.DOS MUNICIPIOS E SUAS ENTIDADES-PRINC.'][df_total_anos.TIPO_INGRESO== 'Transferências de Capital']['TIPO_INGRESO']
# Out:
# 43521     Transferências de Capital
# 113089    Transferências de Capital
# 127529    Transferências de Capital
# 127530    Transferências de Capital
# 127532    Transferências de Capital
# 127533    Transferências de Capital
# 127534    Transferências de Capital
# 127536    Transferências de Capital
# 127537    Transferências de Capital
# 128948    Transferências de Capital
# 128952    Transferências de Capital
# 128953    Transferências de Capital
# 128955    Transferências de Capital
# 128958    Transferências de Capital
# Name: TIPO_INGRESO, dtype: object

# %%
for indice in df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSF.DOS MUNICIPIOS E SUAS ENTIDADES-PRINC.'][df_total_anos.TIPO_INGRESO== 'Transferências de Capital']['TIPO_INGRESO'].index:
    print(indice)
    print(df_total_anos.loc[indice,'TIPO_INGRESO'])
    df_total_anos.loc[indice,'TIPO_INGRESO']= 'Transferências dos Municípios e de suas Entid'
    print(df_total_anos.loc[indice,'TIPO_INGRESO'])
# Out:
# 43521
# Transferências de Capital
# Transferências dos Municípios e de suas Entid
# 113089
# Transferências de Capital
# Transferências dos Municípios e de suas Entid
# 127529
# Transferências de Capital
# Transferências dos Municípios e de suas Entid
# 127530
# Transferências de Capital
# Transferências dos Municípios e de suas Entid
# 127532
# Transferências de Capital
# Transferências dos Municípios e de suas Entid
# 127533
# Transferências de Capital
# Transferências dos Municípios e de suas Entid
# 127534
# Transferências de Capital
# Transferências dos Municípios e de suas Entid
# 127536
# Transferências de Capital
# Transferências dos Municípios e de suas Entid
# 127537
# Transferências de Capital
# Transferências dos Municípios e de suas Entid
# 128948
# Transferências de Capital
# Transferências dos Municípios e de suas Entid
# 128952
# Transferências de Capital
# Transferências dos Municípios e de suas Entid
# 128953
# Transferências de Capital
# ...

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSF.DOS MUNICIPIOS E SUAS ENTIDADES-PRINC.'][df_total_anos.TIPO_INGRESO== 'Transferências de Capital']['TIPO_INGRESO']
# Out:
# Series([], Name: TIPO_INGRESO, dtype: object)

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSF.DOS MUNICIPIOS E SUAS ENTIDADES-PRINC.'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências dos Municípios e de suas Entid    103
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSFERENCIAS DO EXTERIOR-PRINCIPAL'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências do Exterior    17
# Transferências de Capital     13
# Name: count, dtype: int64

# %%
for indice in df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSFERENCIAS DO EXTERIOR-PRINCIPAL'][df_total_anos.TIPO_INGRESO== 'Transferências de Capital']['TIPO_INGRESO'].index:
    print(indice)
    print(df_total_anos.loc[indice,'TIPO_INGRESO'])
    df_total_anos.loc[indice,'TIPO_INGRESO']= 'Transferências do Exterior'
    print(df_total_anos.loc[indice,'TIPO_INGRESO'])
# Out:
# 71882
# Transferências de Capital
# Transferências do Exterior
# 71883
# Transferências de Capital
# Transferências do Exterior
# 71884
# Transferências de Capital
# Transferências do Exterior
# 71885
# Transferências de Capital
# Transferências do Exterior
# 71886
# Transferências de Capital
# Transferências do Exterior
# 71887
# Transferências de Capital
# Transferências do Exterior
# 71888
# Transferências de Capital
# Transferências do Exterior
# 71889
# Transferências de Capital
# Transferências do Exterior
# 71890
# Transferências de Capital
# Transferências do Exterior
# 71891
# Transferências de Capital
# Transferências do Exterior
# 71892
# Transferências de Capital
# Transferências do Exterior
# 71893
# Transferências de Capital
# Transferências do Exterior
# 71894
# Transferências de Capital
# Transferências do Exterior

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSFERENCIAS DO EXTERIOR-PRINCIPAL'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências do Exterior    30
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSFERENCIAS DE INSTITUICOES PRIVADAS-PRINC'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências de Instituições Privadas    120
# Transferências de Capital                    6
# Name: count, dtype: int64

# %%
for indice in df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSFERENCIAS DE INSTITUICOES PRIVADAS-PRINC'][df_total_anos.TIPO_INGRESO== 'Transferências de Capital']['TIPO_INGRESO'].index:
    print(indice)
    print(df_total_anos.loc[indice,'TIPO_INGRESO'])
    df_total_anos.loc[indice,'TIPO_INGRESO']= 'Transferências de Instituições Privadas'
    print(df_total_anos.loc[indice,'TIPO_INGRESO'])
# Out:
# 23507
# Transferências de Capital
# Transferências de Instituições Privadas
# 41654
# Transferências de Capital
# Transferências de Instituições Privadas
# 41711
# Transferências de Capital
# Transferências de Instituições Privadas
# 41713
# Transferências de Capital
# Transferências de Instituições Privadas
# 74224
# Transferências de Capital
# Transferências de Instituições Privadas
# 160716
# Transferências de Capital
# Transferências de Instituições Privadas

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSFERENCIAS DE INSTITUICOES PRIVADAS-PRINC'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências de Instituições Privadas    126
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSF.DOS ESTADOS,DF E SUAS ENTIDADES-PRINC.'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências dos Estados e do Distrito Fede    32
# Transferências de Capital                         3
# Name: count, dtype: int64

# %%
for indice in df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSF.DOS ESTADOS,DF E SUAS ENTIDADES-PRINC.'][df_total_anos.TIPO_INGRESO== 'Transferências de Capital']['TIPO_INGRESO'].index:
    print(indice)
    print(df_total_anos.loc[indice,'TIPO_INGRESO'])
    df_total_anos.loc[indice,'TIPO_INGRESO']= 'Transferências dos Estados e do Distrito Fede'
    print(df_total_anos.loc[indice,'TIPO_INGRESO'])
# Out:
# 43837
# Transferências de Capital
# Transferências dos Estados e do Distrito Fede
# 100416
# Transferências de Capital
# Transferências dos Estados e do Distrito Fede
# 112526
# Transferências de Capital
# Transferências dos Estados e do Distrito Fede

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSF.DOS ESTADOS,DF E SUAS ENTIDADES-PRINC.'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências dos Estados e do Distrito Fede    35
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSFER.DA UNIAO E DE SUAS ENTIDADES-PRINC.'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências da União e de suas Entidades    14
# Transferências de Capital                       2
# Name: count, dtype: int64

# %%
for indice in df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSFER.DA UNIAO E DE SUAS ENTIDADES-PRINC.'][df_total_anos.TIPO_INGRESO== 'Transferências de Capital']['TIPO_INGRESO'].index:
    print(indice)
    print(df_total_anos.loc[indice,'TIPO_INGRESO'])
    df_total_anos.loc[indice,'TIPO_INGRESO']= 'Transferências da União e de suas Entidades'
    print(df_total_anos.loc[indice,'TIPO_INGRESO'])
# Out:
# 36781
# Transferências de Capital
# Transferências da União e de suas Entidades
# 98146
# Transferências de Capital
# Transferências da União e de suas Entidades

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSFER.DA UNIAO E DE SUAS ENTIDADES-PRINC.'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências da União e de suas Entidades    16
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSF.DE OUTRAS INSTITUICOES PUBLICAS-PRINC.'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências de Outras Instituições Pública    5
# Transferências de Capital                        1
# Name: count, dtype: int64

# %%
for indice in df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSF.DE OUTRAS INSTITUICOES PUBLICAS-PRINC.'][df_total_anos.TIPO_INGRESO== 'Transferências de Capital']['TIPO_INGRESO'].index:
    print(indice)
    print(df_total_anos.loc[indice,'TIPO_INGRESO'])
    df_total_anos.loc[indice,'TIPO_INGRESO']= 'Transferências de Outras Instituições Pública'
    print(df_total_anos.loc[indice,'TIPO_INGRESO'])
# Out:
# 195256
# Transferências de Capital
# Transferências de Outras Instituições Pública

# %%
df_total_anos[df_total_anos.ORIGEN_INGRESO == 'Transferências de Capital'][df_total_anos.DETALLE== 'TRANSF.DE OUTRAS INSTITUICOES PUBLICAS-PRINC.'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Transferências de Outras Instituições Pública    6
# Name: count, dtype: int64

# %%
df_total_anos[df_total_anos.CATEGORIA_ECONÓMICA_AGRUPADA == 'Receitas Correntes'].TIPO_INGRESO.value_counts()
# Out:
# TIPO_INGRESO
# Serviços Administrativos e Comerciais Gerais     278157
# Indenizações, restituições e ressarcimentos      143577
# Multas administrativas, contratuais e judicia    115276
# Exploração do patrimônio imobiliário do Estad     88862
# Taxas                                             62336
# Demais receitas correntes                         55079
# Contribuições econômicas                          35123
# Valores Mobiliários                               33037
# Contribuições sociais                             31576
# Exploração de recursos naturais                   21667
# Receita Industrial                                18695
# Impostos                                          16004
# Delegação de Serviços Públicos Mediante Conce     15843
# Serviços e Atividades Referentes à Saúde          14902
# Receita Agropecuária                              13327
# Outros serviços                                    9655
# ...

# %% [markdown]
# ## Guardo el archivo conjunto actualizado

# %%
df_total_anos.to_pickle("../datos/output/datos_all_v1.pkl")
